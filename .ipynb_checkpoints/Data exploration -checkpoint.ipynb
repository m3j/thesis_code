# %% [markdown]
# #### Exploration of the dataset and visualisation thereof.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
metadata = pd.read_csv('../Andet/Metadata/Metadata_fromDrive.tsv', sep = '\t' )

# %%
metadata
# Out:
#         Dataset          ID      Country  gender        age.days.  \
# 0         Huang  SRR6323134        China    male               42
# 1         Huang  SRR6323252        China    male               42
# 2         Huang  SRR6323384        China    male               42
# 3         Huang  SRR6323414        China    male               42
# 4         Huang  SRR6323550        China    male               42
# 5         Huang  SRR6323556        China  female               42
# 6         Huang  SRR6323530        China  female               42
# 7         Huang  SRR6323503        China  female               42
# 8         Huang  SRR6323350        China  female               42
# 9         Huang  SRR6323197        China  female               42
# 10        Huang  SRR6323250        China    male               42
# 11        Huang  SRR6323249        China    male               42
# 12        Huang  SRR6323247        China    male               42
# 13        Huang  SRR6323200        China  female               56
# 14        Huang  SRR6323205        China  female               56
# 15        Huang  SRR6323502        China  female               56
# 16        Huang  SRR6323493        China    male               62
# 17        Huang  SRR6323343        China  female               62
# 18        Huang  SRR6323088        China  female               62
# 19        Huang  SRR6323338        China  female               62
# 20        Huang  SRR6323340        China    male               62
# 21        Huang  SRR6323449        China  female               78
# 22        Huang  SRR6323167        China    male               78
# 23        Huang  SRR6323172        China    male               78
# 24        Huang  SRR6323295        China  female               78
# 25        Huang  SRR6323296        China  female               78
# 26        Huang  SRR6323514        China  female               41
# 27        Huang  SRR6323244        China    male               41
# 28        Huang  SRR6323243        China    male               41
# 29        Huang  SRR6323367        China  female               41
# 30        Huang  SRR6323516        China  female               41
# 31       Gilroy  SRR9113691           UK  female  adult (133-504)
# 32       Gilroy  SRR9113706           UK  female  adult (133-504)
# 33       Gilroy  SRR9113707           UK  female  adult (133-504)
# 34       Gilroy  SRR9113725           UK  female  adult (133-504)
# 35       Gilroy  SRR9113737           UK  female  adult (133-504)
# 36  Patrik Munk  ERR2241647  Netherlands     NaN   33.8 (average)
# 37  Patrik Munk  ERR2241649  Netherlands     NaN   33.8 (average)
# 38  Patrik Munk  ERR2241651  Netherlands     NaN   33.8 (average)
# 39  Patrik Munk  ERR2241653  Netherlands     NaN   33.8 (average)
# 40  Patrik Munk  ERR2241655  Netherlands     NaN   33.8 (average)
# 41  Patrik Munk  ERR2241848        Italy     NaN   33.8 (average)
# 42  Patrik Munk  ERR2241849        Italy     NaN   33.8 (average)
# 43  Patrik Munk  ERR2241855        Italy     NaN   33.8 (average)
# 44  Patrik Munk  ERR2241856        Italy     NaN   33.8 (average)
# 45  Patrik Munk  ERR2241860        Italy     NaN   33.8 (average)
# 46  Patrik Munk  ERR2241919      Denmark     NaN   33.8 (average)
# 47  Patrik Munk  ERR2241923      Denmark     NaN   33.8 (average)
# 48  Patrik Munk  ERR2241925      Denmark     NaN   33.8 (average)
# 49  Patrik Munk  ERR2241927      Denmark     NaN   33.8 (average)
# 50  Patrik Munk  ERR2241945      Denmark     NaN   33.8 (average)
# 51  Patrik Munk  ERR2241887       Poland     NaN   33.8 (average)
# 52  Patrik Munk  ERR2241890       Poland     NaN   33.8 (average)
# 53  Patrik Munk  ERR2241891       Poland     NaN   33.8 (average)
# 54  Patrik Munk  ERR2241893       Poland     NaN   33.8 (average)
# 55  Patrik Munk  ERR2241899       Poland     NaN   33.8 (average)
#
#                             Breed isolation.location     type  \
# 0             Arbor Acres broiler              cecum  broiler
# 1             Arbor Acres broiler           duodenum  broiler
# 2             Arbor Acres broiler              ileum  broiler
# 3             Arbor Acres broiler            jejunum  broiler
# 4             Arbor Acres broiler         colorectum  broiler
# 5   Local yellow-feather chickens              cecum    layer
# 6   Local yellow-feather chickens              ileum    layer
# 7   Local yellow-feather chickens         colorectum    layer
# 8   Local yellow-feather chickens            jejunum    layer
# 9   Local yellow-feather chickens           duodenum    layer
# 10            Arbor Acres broiler              cecum  broiler
# 11            Arbor Acres broiler              cecum  broiler
# 12            Arbor Acres broiler              cecum  broiler
# 13  Local yellow-feather chickens              cecum    layer
# 14  Local yellow-feather chickens              cecum    layer
# 15  Local yellow-feather chickens         colorectum    layer
# 16           Yellow dwarf chicken         colorectum  broiler
# 17           Yellow dwarf chicken         colorectum  broiler
# 18           Yellow dwarf chicken              cecum  broiler
# 19           Yellow dwarf chicken         colorectum  broiler
# 20           Yellow dwarf chicken              cecum  broiler
# 21          Guangxi local chicken              cecum  broiler
# 22          Guangxi local chicken         colorectum  broiler
# 23          Guangxi local chicken         colorectum  broiler
# 24          Guangxi local chicken         colorectum  broiler
# 25          Guangxi local chicken         colorectum  broiler
# 26                       Ross 308              cecum  broiler
# 27                       Ross 308              cecum  broiler
# 28                       Ross 308              cecum  broiler
# 29                       Ross 308         colorectum  broiler
# 30                       Ross 308              cecum  broiler
# 31                  Lohmann Brown             Faecal    layer
# 32                  Lohmann Brown             Faecal    layer
# 33                  Lohmann Brown             Faecal    layer
# 34                  Lohmann Brown             Faecal    layer
# 35                  Lohmann Brown             Faecal    layer
# 36                            NaN             Faecal  broiler
# 37                            NaN             Faecal  broiler
# 38                            NaN             Faecal  broiler
# 39                            NaN             Faecal  broiler
# 40                            NaN             Faecal  broiler
# 41                            NaN             Faecal  broiler
# 42                            NaN             Faecal  broiler
# 43                            NaN             Faecal  broiler
# 44                            NaN             Faecal  broiler
# 45                            NaN             Faecal  broiler
# 46                            NaN             Faecal  broiler
# 47                            NaN             Faecal  broiler
# 48                            NaN             Faecal  broiler
# 49                            NaN             Faecal  broiler
# 50                            NaN             Faecal  broiler
# 51                            NaN             Faecal  broiler
# 52                            NaN             Faecal  broiler
# 53                            NaN             Faecal  broiler
# 54                            NaN             Faecal  broiler
# 55                            NaN             Faecal  broiler
#
#                                                  Feed  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                      not collected
# 17                                      not collected
# 18                                      not collected
# 19                                      not collected
# 20                                      not collected
# 21                                      not collected
# 22                                      not collected
# 23                                      not collected
# 24                                      not collected
# 25                                      not collected
# 26                                      not collected
# 27                                      not collected
# 28                                      not collected
# 29                                      not collected
# 30                                      not collected
# 31  Farmgate Layer pellet and mash(ForFarmers UK l...
# 32  Farmgate Layer pellet and mash(ForFarmers UK l...
# 33  Farmgate Layer pellet and mash(ForFarmers UK l...
# 34  Farmgate Layer pellet and mash(ForFarmers UK l...
# 35  Farmgate Layer pellet and mash(ForFarmers UK l...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
#
#                                           Temperature  ...  \
# 0   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 1   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 2   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 3   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 4   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 5   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 6   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 7   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 8   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 9   reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 10  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 11  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 12  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 13  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 14  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 15  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 16  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 17  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 18  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 19  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 20  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 21  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 22  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 23  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 24  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 25  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 26  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 27  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 28  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 29  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 30  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 31                                                NaN  ...
# 32                                                NaN  ...
# 33                                                NaN  ...
# 34                                                NaN  ...
# 35                                                NaN  ...
# 36                                                NaN  ...
# 37                                                NaN  ...
# 38                                                NaN  ...
# 39                                                NaN  ...
# 40                                                NaN  ...
# 41                                                NaN  ...
# 42                                                NaN  ...
# 43                                                NaN  ...
# 44                                                NaN  ...
# 45                                                NaN  ...
# 46                                                NaN  ...
# 47                                                NaN  ...
# 48                                                NaN  ...
# 49                                                NaN  ...
# 50                                                NaN  ...
# 51                                                NaN  ...
# 52                                                NaN  ...
# 53                                                NaN  ...
# 54                                                NaN  ...
# 55                                                NaN  ...
#
#                                               vaccine vægt humidity  \
# 0   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 1   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 2   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 3   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 4   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 5   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 6   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 7   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 8   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 9   Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 10  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 11  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 12  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 13  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 14  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 15  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 16  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 17  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 18  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 19  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 20  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 21  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 22  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 23  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 24  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 25  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 26  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 27  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 28  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 29  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 30  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 31                                                NaN  NaN      NaN
# 32                                                NaN  NaN      NaN
# 33                                                NaN  NaN      NaN
# 34                                                NaN  NaN      NaN
# 35                                                NaN  NaN      NaN
# 36                                                NaN  NaN      NaN
# 37                                                NaN  NaN      NaN
# 38                                                NaN  NaN      NaN
# 39                                                NaN  NaN      NaN
# 40                                                NaN  NaN      NaN
# 41                                                NaN  NaN      NaN
# 42                                                NaN  NaN      NaN
# 43                                                NaN  NaN      NaN
# 44                                                NaN  NaN      NaN
# 45                                                NaN  NaN      NaN
# 46                                                NaN  NaN      NaN
# 47                                                NaN  NaN      NaN
# 48                                                NaN  NaN      NaN
# 49                                                NaN  NaN      NaN
# 50                                                NaN  NaN      NaN
# 51                                                NaN  NaN      NaN
# 52                                                NaN  NaN      NaN
# 53                                                NaN  NaN      NaN
# 54                                                NaN  NaN      NaN
# 55                                                NaN  NaN      NaN
#
#         sequencing.method  DNA.extraction  \
# 0             HiSeq X Ten             NaN
# 1             HiSeq X Ten             NaN
# 2             HiSeq X Ten             NaN
# 3             HiSeq X Ten             NaN
# 4             HiSeq X Ten             NaN
# 5             HiSeq X Ten             NaN
# 6             HiSeq X Ten             NaN
# 7             HiSeq X Ten             NaN
# 8             HiSeq X Ten             NaN
# 9             HiSeq X Ten             NaN
# 10            HiSeq X Ten             NaN
# 11            HiSeq X Ten             NaN
# 12            HiSeq X Ten             NaN
# 13    Illumina HiSeq 2500             NaN
# 14            HiSeq X Ten             NaN
# 15            HiSeq X Ten             NaN
# 16    Illumina HiSeq 2500             NaN
# 17            HiSeq X Ten             NaN
# 18    Illumina HiSeq 2500             NaN
# 19    Illumina HiSeq 2500             NaN
# 20            HiSeq X Ten             NaN
# 21    Illumina HiSeq 2500             NaN
# 22    Illumina HiSeq 2500             NaN
# 23    Illumina HiSeq 2500             NaN
# 24    Illumina HiSeq 2500             NaN
# 25            HiSeq X Ten             NaN
# 26    Illumina HiSeq 2500             NaN
# 27    Illumina HiSeq 2500             NaN
# 28    Illumina HiSeq 2500             NaN
# 29    Illumina HiSeq 2500             NaN
# 30            HiSeq X Ten             NaN
# 31  Illumina NovaSeq 6000             NaN
# 32  Illumina NovaSeq 6000             NaN
# 33  Illumina NovaSeq 6000             NaN
# 34  Illumina NovaSeq 6000             NaN
# 35  Illumina NovaSeq 6000             NaN
# 36    Illumina HiSeq 3000             NaN
# 37    Illumina HiSeq 3000             NaN
# 38    Illumina HiSeq 3000             NaN
# 39    Illumina HiSeq 3000             NaN
# 40    Illumina HiSeq 3000             NaN
# 41    Illumina HiSeq 3000             NaN
# 42    Illumina HiSeq 3000             NaN
# 43    Illumina HiSeq 3000             NaN
# 44    Illumina HiSeq 3000             NaN
# 45    Illumina HiSeq 3000             NaN
# 46    Illumina HiSeq 3000             NaN
# 47    Illumina HiSeq 3000             NaN
# 48    Illumina HiSeq 3000             NaN
# 49    Illumina HiSeq 3000             NaN
# 50    Illumina HiSeq 3000             NaN
# 51    Illumina HiSeq 3000             NaN
# 52    Illumina HiSeq 3000             NaN
# 53    Illumina HiSeq 3000             NaN
# 54    Illumina HiSeq 3000             NaN
# 55    Illumina HiSeq 3000             NaN
#
#                                      Sample.replicate     location_name.farm  \
# 0                   pooled digesta from five chickens          China:Beijing
# 1                   pooled digesta from five chickens          China:Beijing
# 2                   pooled digesta from five chickens          China:Beijing
# 3                   pooled digesta from five chickens          China:Beijing
# 4                   pooled digesta from five chickens          China:Beijing
# 5                   pooled digesta from five chickens            China:Hunan
# 6                   pooled digesta from five chickens            China:Hunan
# 7                   pooled digesta from five chickens            China:Hunan
# 8                   pooled digesta from five chickens            China:Hunan
# 9                   pooled digesta from five chickens            China:Hunan
# 10  digesta from one chicken (biological replicate 2)          China:Beijing
# 11  digesta from one chicken (biological replicate 1)          China:Beijing
# 12  digesta from one chicken (biological replicate 3)          China:Beijing
# 13  digesta from one chicken (biological replicate 3)            China:Hunan
# 14  digesta from one chicken (biological replicate 2)            China:Hunan
# 15  digesta from one chicken (biological replicate 1)            China:Hunan
# 16  digesta from one chicken (biological replicate 1)         China:Guandong
# 17  digesta from one chicken (biological replicate 2)         China:Guandong
# 18  digesta from one chicken (biological replicate 1)         China:Guandong
# 19  digesta from one chicken (biological replicate 3)         China:Guandong
# 20  digesta from one chicken (biological replicate 2)         China:Guandong
# 21  digesta from one chicken (biological replicate 3)            China:Hunan
# 22  digesta from one chicken (biological replicate 2)            China:Hunan
# 23  digesta from one chicken (biological replicate 1)            China:Hunan
# 24  digesta from one chicken (biological replicate 1)            China:Hunan
# 25  digesta from one chicken (biological replicate 2)            China:Hunan
# 26  digesta from one chicken (biological replicate 1)           China:Shanxi
# 27  digesta from one chicken (biological replicate 2)           China:Shanxi
# 28  digesta from one chicken (biological replicate 3)           China:Shanxi
# 29  digesta from one chicken (biological replicate 2)           China:Shanxi
# 30  digesta from one chicken (biological replicate 3)           China:Shanxi
# 31                           digesta from one chicken  UK:South-east England
# 32                           digesta from one chicken  UK:South-east England
# 33                           digesta from one chicken  UK:South-east England
# 34                           digesta from one chicken  UK:South-east England
# 35                           digesta from one chicken  UK:South-east England
# 36                    pooled digesta from 25 chickens                     NL
# 37                    pooled digesta from 25 chickens                     NL
# 38                    pooled digesta from 25 chickens                     NL
# 39                    pooled digesta from 25 chickens                     NL
# 40                    pooled digesta from 25 chickens                     NL
# 41                    pooled digesta from 25 chickens                    ITA
# 42                    pooled digesta from 25 chickens                    ITA
# 43                    pooled digesta from 25 chickens                    ITA
# 44                    pooled digesta from 25 chickens                    ITA
# 45                    pooled digesta from 25 chickens                    ITA
# 46                    pooled digesta from 25 chickens                    DEN
# 47                    pooled digesta from 25 chickens                    DEN
# 48                    pooled digesta from 25 chickens                    DEN
# 49                    pooled digesta from 25 chickens                    DEN
# 50                    pooled digesta from 25 chickens                    DEN
# 51                    pooled digesta from 25 chickens                    POL
# 52                    pooled digesta from 25 chickens                    POL
# 53                    pooled digesta from 25 chickens                    POL
# 54                    pooled digesta from 25 chickens                    POL
# 55                    pooled digesta from 25 chickens                    POL
#
#    farm_ID G bases avg Gbases
# 0   china1     2.4        NaN
# 1   china1     2.8        NaN
# 2   china1     2.6        NaN
# 3   china1     3.0        NaN
# 4   china1     3.0        NaN
# 5   china2     4.6        NaN
# 6   china2     2.5        NaN
# 7   china2     4.2        NaN
# 8   china2     1.7        NaN
# 9   china2     3.2        NaN
# 10  china3     3.5        NaN
# 11  china3     3.1        NaN
# 12  china3     2.8        NaN
# 13  china4     5.0        NaN
# 14  china4     7.2        NaN
# 15  china4     7.4        NaN
# 16  china5     4.7        NaN
# 17  china5     5.5        NaN
# 18  china5     4.6        NaN
# 19  china5     5.1        NaN
# 20  china5     6.9        NaN
# 21  china6     4.1        NaN
# 22  china6     3.9        NaN
# 23  china6     3.4        NaN
# 24  china6     3.3        NaN
# 25  china6     5.7        NaN
# 26  china7     4.2        NaN
# 27  china7     4.4        NaN
# 28  china7     4.7        NaN
# 29  china7     4.3        NaN
# 30  china7     5.7   4.177419
# 31      UK     6.7        NaN
# 32      UK     5.8        NaN
# 33      UK     6.0        NaN
# 34      UK     5.7        NaN
# 35      UK     5.8   6.000000
# 36      NL    14.4        NaN
# 37      NL    14.1        NaN
# 38      NL    15.4        NaN
# 39      NL    13.3        NaN
# 40      NL    12.3        NaN
# 41     ITA    13.5        NaN
# 42     ITA    14.5        NaN
# 43     ITA    13.0        NaN
# 44     ITA    12.8        NaN
# 45     ITA    11.7        NaN
# 46     DEN    14.1        NaN
# 47     DEN    14.1        NaN
# 48     DEN    15.9        NaN
# 49     DEN    11.8        NaN
# 50     DEN    15.1        NaN
# 51     POL    16.4        NaN
# 52     POL    17.9        NaN
# 53     POL    14.2        NaN
# 54     POL    15.3        NaN
# 55     POL    13.9  14.185000
#
# [56 rows x 22 columns]

# %%
metadata['Dataset'] = metadata['Dataset'].str.replace('Huang','dChina')

# %%
metadata['Dataset'] = metadata['Dataset'].str.replace('Gilroy','dSurrey')

# %%
metadata['Dataset'] = metadata['Dataset'].str.replace('Patrik Munk','dEFFORT')

# %%
sns.boxplot(metadata['G bases'].astype(int), 
            metadata['Dataset'], palette="Paired")
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.ylabel('')
plt.xlabel('G bases', fontsize=12)

plt.savefig('resultFigs/dataset_Gbases_boxplot.png',  bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
metadata.groupby('Dataset').sum()['G bases']
# Out:
# Dataset
# dChina     129.5
# dEFFORT    283.7
# dSurrey     30.0
# Name: G bases, dtype: float64

# %%
sns.barplot(x=metadata.groupby('Dataset').sum()['G bases'], hue=metadata['Dataset'])
# Out:
# <AxesSubplot:xlabel='G bases'>

# %%
sns.histplot(x=metadata['G bases'], hue=metadata['Dataset'], binwidth=0.8)
# Out:
# <AxesSubplot:xlabel='G bases', ylabel='Count'>
