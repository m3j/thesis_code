# %%
import pandas as pd 
import numpy as np
import re

# %% [markdown]
# ### Connecting runs with sampels
# In order to connect sample Ids with run ids the only key I had was the number of reads. This notebook contains some steps regarding this process:
#
# 1)
# the read count I had was forward and reverse combined so I divided this into two to avoid counting both forward and reverse reads. And saved it as a csv file to use as input in the script
#
# 2)
# Then I made the script count_read_to_match_id.py - The output was not as hoped since none of the read counts matched any of the counts I had been given - but here is the list of the acctual counts in the reads.

# %% [markdown]
# ###  1) Dividing the reads in two

# %%
NZ_reads = pd.read_csv('3regionData/Sample_Rawreads_NZ.tsv', sep = '\t')

# %%
NZ_reads['#Rawreads'] = NZ_reads['#Rawreads'].astype(int)

# %%
NZ_reads['#Rawreads']
# Out:
# 0      265275932
# 1      261070644
# 2      259086484
# 3      246402572
# 4      244068892
#          ...
# 316    102916696
# 317     99312498
# 318     98078308
# 319     96545846
# 320     42722198
# Name: #Rawreads, Length: 321, dtype: int64

# %%
NZ_reads['#Rawreads'] = NZ_reads['#Rawreads']/2

# %%
NZ_reads['#Rawreads'] = NZ_reads['#Rawreads'].astype(int)

# %%
NZ_reads
# Out:
#           Sample  #Rawreads
# 0      F1606-058  132637966
# 1      F1604-045  130535322
# 2      F1604-007  129543242
# 3      F1605-009  123201286
# 4      F1604-022  122034446
# ..           ...        ...
# 316    F1513-219   51458348
# 317    F1602_059   49656249
# 318    F1604_039   49039154
# 319  F1608_001_3   48272923
# 320    F1513-078   21361099
#
# [321 rows x 2 columns]

# %%
NZ_reads.to_csv('NZ_samples_1read_ID.csv', index=False)

# %% [markdown]
# ### 2) cleaning output from script saving the read counts

# %%
script_output = pd.read_csv('3regionData/33773072.qsub_read_match_id.stdout', header = None)

# %%
script_output
# Out:
#                                                      0
# 0                           CL100023189_L02_38_1.fq.gz
# 1                            CL100006258_L01_7_1.fq.gz
# 2                           CL100017972_L02_11_1.fq.gz
# 3                            CL100006258_L01_4_1.fq.gz
# 4                            CL100017973_L01_1_1.fq.gz
# ..                                                 ...
# 634  82069540  was not present as read count in the...
# 635  82787491  was not present as read count in the...
# 636  81837025  was not present as read count in the...
# 637  59731009  was not present as read count in the...
# 638  75242807  was not present as read count in the...
#
# [639 rows x 1 columns]

# %%
files = script_output.loc[script_output[0].str.startswith('CL', na=False)]

# %%
reads = script_output.iloc[319:]

# %%
reads
# Out:
#             0
# 319  89082404
# 320  66217371
# 321  88436484
# 322  53064542
# 323  91208499
# ..        ...
# 634  82069540
# 635  82787491
# 636  81837025
# 637  59731009
# 638  75242807
#
# [320 rows x 1 columns]

# %%
reads[0] = reads[0].str.extract('(\d+)', expand=False)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
reads= reads.rename({0: 'read_count'}, axis=1)

# %%
files = files.rename({0: 'run_id'}, axis=1)

# %%
files
# Out:
#                          run_id
# 0    CL100023189_L02_38_1.fq.gz
# 1     CL100006258_L01_7_1.fq.gz
# 2    CL100017972_L02_11_1.fq.gz
# 3     CL100006258_L01_4_1.fq.gz
# 4     CL100017973_L01_1_1.fq.gz
# ..                          ...
# 314  CL100020401_L02_10_1.fq.gz
# 315  CL100017972_L02_12_1.fq.gz
# 316   CL100020404_L01_1_1.fq.gz
# 317  CL100006258_L02_13_1.fq.gz
# 318  CL100017863_L02_16_1.fq.gz
#
# [319 rows x 1 columns]

# %%
reads['read_count'] = reads['read_count'].astype(int)

# %%
reads['read_count'].max()
# Out:
# 134677219

# %%
#removing the value 0 which was in there. 
reads = reads[reads.read_count != 0]

# %%
reads.min()
# Out:
# read_count    16998916
# dtype: int64

# %%
files['read_count'] = reads['read_count']

# %%
files
# Out:
#                          run_id  read_count
# 0    CL100023189_L02_38_1.fq.gz         NaN
# 1     CL100006258_L01_7_1.fq.gz         NaN
# 2    CL100017972_L02_11_1.fq.gz         NaN
# 3     CL100006258_L01_4_1.fq.gz         NaN
# 4     CL100017973_L01_1_1.fq.gz         NaN
# ..                          ...         ...
# 314  CL100020401_L02_10_1.fq.gz         NaN
# 315  CL100017972_L02_12_1.fq.gz         NaN
# 316   CL100020404_L01_1_1.fq.gz         NaN
# 317  CL100006258_L02_13_1.fq.gz         NaN
# 318  CL100017863_L02_16_1.fq.gz         NaN
#
# [319 rows x 2 columns]

# %%
output = dict(zip(files['run_id'], reads['read_count']))

# %%
output
# Out:
# {'CL100023189_L02_38_1.fq.gz': 89082404,
#  'CL100006258_L01_7_1.fq.gz': 66217371,
#  'CL100017972_L02_11_1.fq.gz': 88436484,
#  'CL100006258_L01_4_1.fq.gz': 53064542,
#  'CL100017973_L01_1_1.fq.gz': 91208499,
#  'CL100020401_L02_9_1.fq.gz': 103305735,
#  'CL100020243_L01_21_1.fq.gz': 85218066,
#  'CL100013689_L01_16_1.fq.gz': 86089720,
#  'CL100020401_L02_13_1.fq.gz': 72821190,
#  'CL100020425_L02_40_1.fq.gz': 63909128,
#  'CL100013751_L02_4_1.fq.gz': 81692793,
#  'CL100017863_L02_11_1.fq.gz': 82309896,
#  'CL100020456_L02_35_1.fq.gz': 92152731,
#  'CL100006258_L02_12_1.fq.gz': 50373388,
#  'CL100006210_L02_14_1.fq.gz': 64511983,
#  'CL100013749_L01_10_1.fq.gz': 66936795,
#  'CL100020244_L01_3_1.fq.gz': 53883929,
#  'CL100013751_L02_1_1.fq.gz': 81976836,
#  'CL100006375_L02_16_1.fq.gz': 82851543,
#  'CL100013751_L01_16_1.fq.gz': 98988795,
#  'CL100006258_L01_5_1.fq.gz': 58350228,
#  'CL100020242_L02_12_1.fq.gz': 72501157,
#  'CL100017975_L01_2_1.fq.gz': 81153810,
#  'CL100013751_L02_5_1.fq.gz': 80694470,
#  'CL100017971_L02_9_1.fq.gz': 73327784,
#  'CL100013749_L02_2_1.fq.gz': 87945349,
#  'CL100020404_L02_16_1.fq.gz': 84044011,
#  'CL100020243_L01_18_1.fq.gz': 77135941,
#  'CL100020425_L02_39_1.fq.gz': 86499466,
#  'CL100020401_L02_12_1.fq.gz': 63878103,
#  'CL100006258_L02_14_1.fq.gz': 49749177,
#  'CL100017863_L02_15_1.fq.gz': 81098793,
#  'CL100020401_L01_6_1.fq.gz': 86934635,
#  'CL100006258_L02_10_1.fq.gz': 52685259,
#  'CL100006210_L02_13_1.fq.gz': 53583139,
#  'CL100020242_L02_10_1.fq.gz': 77477923,
#  'CL100020565_L02_15_1.fq.gz': 63195119,
#  'CL100017863_L01_6_1.fq.gz': 71655780,
#  'CL100020456_L01_23_1.fq.gz': 99277199,
#  'CL100020401_L02_10_1.fq.gz': 82069540,
#  'CL100017972_L02_12_1.fq.gz': 82787491,
#  'CL100020404_L01_1_1.fq.gz': 81837025,
#  'CL100006258_L02_13_1.fq.gz': 59731009,
#  'CL100017863_L02_16_1.fq.gz': 75242807}

# %% [markdown]
# 294016368/4 = 73504092.0 is the number of reads in CL100013689_L01_15_1.fq.gz - just to check if it fits with the row below since there is 0 in the middle of the reads and a read count more than there is files!
#
# With another method i counted 107 of the files:

# %%
CountMethod2 = pd.read_csv('3regionData/1third_count.tsv', sep = '\t', header=None)

# %%
CountMethod2 = CountMethod2.rename({0: 'line_count', 1: 'filepath'}, axis=1)

# %%
CountMethod2
# Out:
#      line_count                                       filepath
# 0     269026252  CL100006210_L01_1_1/CL100006210_L01_1_1.fq.gz
# 1     249986008  CL100006210_L01_2_1/CL100006210_L01_2_1.fq.gz
# 2     250339448  CL100006210_L01_3_1/CL100006210_L01_3_1.fq.gz
# 3     257594976  CL100006210_L01_4_1/CL100006210_L01_4_1.fq.gz
# 4     328774404  CL100006210_L01_5_1/CL100006210_L01_5_1.fq.gz
# ..          ...                                            ...
# 102   267874940  CL100017863_L02_9_1/CL100017863_L02_9_1.fq.gz
# 103   286007488  CL100017968_L01_1_1/CL100017968_L01_1_1.fq.gz
# 104   518172968  CL100017968_L01_2_1/CL100017968_L01_2_1.fq.gz
# 105   309683268  CL100017968_L01_3_1/CL100017968_L01_3_1.fq.gz
# 106   261035132  CL100017968_L01_4_1/CL100017968_L01_4_1.fq.gz
#
# [107 rows x 2 columns]

# %%
CountMethod2['read_count'] = (CountMethod2['line_count']/4).astype(int)

# %%
CountMethod2['run_id'] = CountMethod2['filepath'].str.split('/', expand=True)[1]

# %%
CountMethod2
# Out:
#      line_count                                       filepath  read_count  \
# 0     269026252  CL100006210_L01_1_1/CL100006210_L01_1_1.fq.gz    67256563
# 1     249986008  CL100006210_L01_2_1/CL100006210_L01_2_1.fq.gz    62496502
# 2     250339448  CL100006210_L01_3_1/CL100006210_L01_3_1.fq.gz    62584862
# 3     257594976  CL100006210_L01_4_1/CL100006210_L01_4_1.fq.gz    64398744
# 4     328774404  CL100006210_L01_5_1/CL100006210_L01_5_1.fq.gz    82193601
# ..          ...                                            ...         ...
# 102   267874940  CL100017863_L02_9_1/CL100017863_L02_9_1.fq.gz    66968735
# 103   286007488  CL100017968_L01_1_1/CL100017968_L01_1_1.fq.gz    71501872
# 104   518172968  CL100017968_L01_2_1/CL100017968_L01_2_1.fq.gz   129543242
# 105   309683268  CL100017968_L01_3_1/CL100017968_L01_3_1.fq.gz    77420817
# 106   261035132  CL100017968_L01_4_1/CL100017968_L01_4_1.fq.gz    65258783
#
#                         run_id
# 0    CL100006210_L01_1_1.fq.gz
# 1    CL100006210_L01_2_1.fq.gz
# 2    CL100006210_L01_3_1.fq.gz
# 3    CL100006210_L01_4_1.fq.gz
# 4    CL100006210_L01_5_1.fq.gz
# ..                         ...
# 102  CL100017863_L02_9_1.fq.gz
# 103  CL100017968_L01_1_1.fq.gz
# 104  CL100017968_L01_2_1.fq.gz
# 105  CL100017968_L01_3_1.fq.gz
# 106  CL100017968_L01_4_1.fq.gz
#
# [107 rows x 4 columns]

# %%
CountMethod2_dict = dict(zip(CountMethod2['run_id'], CountMethod2['read_count']))

# %%
for key in CountMethod2_dict:
    if not key in output:
        continue
    print('CountMethod2', output[key])
    print('third', CountMethod2_dict[key])
    print('difference:',output[key]-CountMethod2_dict[key])
# Out:
# CountMethod2 68157182
# third 67256563
# difference: 900619
# CountMethod2 63325973
# third 62496502
# difference: 829471
# CountMethod2 63416656
# third 62584862
# difference: 831794
# CountMethod2 65264742
# third 64398744
# difference: 865998
# CountMethod2 83297831
# third 82193601
# difference: 1104230
# CountMethod2 82098018
# third 81003026
# difference: 1094992
# CountMethod2 76355522
# third 75346943
# difference: 1008579
# CountMethod2 70469654
# third 69540530
# difference: 929124
# CountMethod2 66084826
# third 65179627
# difference: 905199
# CountMethod2 68700247
# third 67759374
# difference: 940873
# CountMethod2 56526207
# third 55747891
# difference: 778316
# CountMethod2 53583139
# third 52842620
# difference: 740519
# CountMethod2 64511983
# third 63614106
# difference: 897877
# CountMethod2 58883901
# third 58076757
# difference: 807144
# CountMethod2 62235748
# third 61389838
# difference: 845910
# CountMethod2 65633752
# third 64743018
# difference: 890734
# CountMethod2 58433970
# third 57544461
# difference: 889509
# CountMethod2 55987899
# third 55141990
# difference: 845909
# CountMethod2 49016804
# third 48272923
# difference: 743881
# CountMethod2 53064542
# third 52260645
# difference: 803897
# CountMethod2 58350228
# third 57453943
# difference: 896285
# CountMethod2 52418359
# third 51621902
# difference: 796457
# CountMethod2 66217371
# third 65209302
# difference: 1008069
# CountMethod2 55340446
# third 54487954
# difference: 852492
# CountMethod2 52685259
# third 51921768
# difference: 763491
# CountMethod2 62452412
# third 61557917
# difference: 894495
# CountMethod2 50373388
# third 49656249
# difference: 717139
# CountMethod2 59731009
# third 58868431
# difference: 862578
# CountMethod2 49749177
# third 49039154
# difference: 710023
# CountMethod2 59522975
# third 58665047
# difference: 857928
# CountMethod2 76335396
# third 75252277
# difference: 1083119
# CountMethod2 61952681
# third 61069056
# difference: 883625
# CountMethod2 72893332
# third 71769137
# difference: 1124195
# CountMethod2 60761993
# third 59803212
# difference: 958781
# CountMethod2 63654448
# third 62665530
# difference: 988918
# CountMethod2 67589699
# third 66539565
# difference: 1050134
# CountMethod2 70357866
# third 69271527
# difference: 1086339
# CountMethod2 56576075
# third 55714611
# difference: 861464
# CountMethod2 72990375
# third 71858548
# difference: 1131827
# CountMethod2 75038981
# third 73914100
# difference: 1124881
# CountMethod2 67142938
# third 66429537
# difference: 713401
# CountMethod2 80982879
# third 80108990
# difference: 873889
# CountMethod2 65166709
# difference: 918341
# CountMethod2 75583773
# third 74486731
# difference: 1097042
# CountMethod2 81098793
# third 79881759
# difference: 1217034
# CountMethod2 75242807
# third 74106569
# difference: 1136238
# CountMethod2 67995633
# third 66968735
# difference: 1026898
# CountMethod2 72754665
# third 71501872
# difference: 1252793
# CountMethod2 131729885
# third 129543242
# difference: 2186643
# CountMethod2 78753237
# third 77420817
# difference: 1332420
# CountMethod2 66386978
# third 65258783
# difference: 1128195

# %% [markdown]
# So it looks like the thirdOfCount is alwas a little smaller than the output from the script. But do ane of them match the information given to fit with the samople id?

# %%
original_info = pd.read_csv('3regionData/original_reads_information.tsv', sep='\t')

# %%
original_info
# Out:
#           Sample  #Rawreads  Readslength(bp)  #HQpaid-endreads1  \
# 0      F1606-058  265275932               50          131599927
# 1      F1604-045  261070644               50          129643702
# 2      F1604-007  259086484               50          129014882
# 3      F1605-009  246402572               50          122496781
# 4      F1604-022  244068892               50          119005624
# ..           ...        ...              ...                ...
# 316    F1513-219  102916696               50           51099361
# 317    F1602_059   99312498               50           48707098
# 318    F1604_039   98078308               50           48121477
# 319  F1608_001_3   96545846               50           47803574
# 320    F1513-078   42722198               50           21297674
#
#      #HQpaid-endreads2   #HQreads HQratio  #HQrmhostpair-endreads  \
# 0            131804460  263404387  99,29%               262172374
# 1            128649729  258293431  98,94%               247631872
# 2            127202704  256217586  98,89%               251849712
# 3            121421860  243918641  98,99%               241657802
# 4            120093489  239099113  97,96%               234821120
# ..                 ...        ...     ...                     ...
# 316           50050219  101149580  98,28%                98091930
# 317           47488125   96195223  96,86%                92961620
# 318           46798300   94919777  96,78%                91685194
# 319           45679067   93482641  96,83%                89311980
# 320           20747359   42045033  98,41%                33033962
#
#      #HQrmhostsingle-endreads  #HQrmhostreads
# 0                     1112195       263284569
# 1                     1975945       249607817
# 2                     2108939       253958651
# 3                     1929195       243586997
# 4                     3275255       238096375
# ..                        ...             ...
# 316                   1305042        99396972
# 317                   2656802        95618422
# 318                   2711398        94396592
# 319                   2670124        91982104
# 320                    540053        33574015
#
# [321 rows x 10 columns]

# %%
def matching_dict_with_orignal(reads_dict, original_reads_step):
    for read in (original_info[original_reads_step]/2).astype(int):
        for key in reads_dict:
            if reads_dict[key] == read:
                print('there was a match for', key,'with reads count',read)

# %%
matching_dict_with_orignal(output, '#Rawreads')

# %%
matching_dict_with_orignal(output, '#HQreads')

# %%
matching_dict_with_orignal(output, '#HQrmhostreads')

# %%
matching_dict_with_orignal(CountMethod2_dict, '#Rawreads')
# Out:
# there was a match for CL100017968_L01_2_1.fq.gz with reads count 129543242
# there was a match for CL100013749_L01_9_1.fq.gz with reads count 103904714
# there was a match for CL100013749_L02_7_1.fq.gz with reads count 100133592
# there was a match for CL100013749_L02_1_1.fq.gz with reads count 99861406
# there was a match for CL100017863_L01_2_1.fq.gz with reads count 98196243
# there was a match for CL100013751_L01_16_1.fq.gz with reads count 97861926
# there was a match for CL100013749_L01_11_1.fq.gz with reads count 91393769
# there was a match for CL100013749_L01_16_1.fq.gz with reads count 91337159
# there was a match for CL100013751_L02_7_1.fq.gz with reads count 88950737
# there was a match for CL100013749_L01_15_1.fq.gz with reads count 87562969
# there was a match for CL100013749_L02_2_1.fq.gz with reads count 86871175
# there was a match for CL100006375_L02_13_1.fq.gz with reads count 86788219
# there was a match for CL100013689_L01_16_1.fq.gz with reads count 85046754
# there was a match for CL100013751_L02_2_1.fq.gz with reads count 84761248
# there was a match for CL100006375_L02_9_1.fq.gz with reads count 84006586
# there was a match for CL100017863_L02_12_1.fq.gz with reads count 83413396
# there was a match for CL100013751_L01_9_1.fq.gz with reads count 82530431
# there was a match for CL100013751_L01_13_1.fq.gz with reads count 82441957
# there was a match for CL100013751_L01_15_1.fq.gz with reads count 82309961
# there was a match for CL100006210_L01_5_1.fq.gz with reads count 82193601
# there was a match for CL100006375_L02_16_1.fq.gz with reads count 81967251
# there was a match for CL100013751_L02_1_1.fq.gz with reads count 81091240
# there was a match for CL100017863_L02_11_1.fq.gz with reads count 81072913
# there was a match for CL100013689_L01_11_1.fq.gz with reads count 81007797
# there was a match for CL100006210_L01_6_1.fq.gz with reads count 81003026
# there was a match for CL100013751_L02_4_1.fq.gz with reads count 80820121
# there was a match for CL100006375_L02_11_1.fq.gz with reads count 80108990
# there was a match for CL100017863_L02_15_1.fq.gz with reads count 79881759
# there was a match for CL100013751_L02_5_1.fq.gz with reads count 79809355
# there was a match for CL100017863_L01_7_1.fq.gz with reads count 78960503
# there was a match for CL100017863_L01_1_1.fq.gz with reads count 77820058
# there was a match for CL100013751_L01_11_1.fq.gz with reads count 77597823
# there was a match for CL100017968_L01_3_1.fq.gz with reads count 77420817
# there was a match for CL100013749_L01_14_1.fq.gz with reads count 75988063
# there was a match for CL100006210_L01_7_1.fq.gz with reads count 75346943
# there was a match for CL100006375_L02_15_1.fq.gz with reads count 75287628
# there was a match for CL100006258_L02_16_1.fq.gz with reads count 75252277
# there was a match for CL100013749_L02_8_1.fq.gz with reads count 74516614
# there was a match for CL100017863_L02_14_1.fq.gz with reads count 74486731
# there was a match for CL100017863_L02_16_1.fq.gz with reads count 74106569
# there was a match for CL100006375_L01_8_1.fq.gz with reads count 73914100
# there was a match for CL100013689_L01_15_1.fq.gz with reads count 73504092
# there was a match for CL100013689_L01_14_1.fq.gz with reads count 72881398
# there was a match for CL100013751_L02_6_1.fq.gz with reads count 72549916
# there was a match for CL100017863_L01_5_1.fq.gz with reads count 72214402
# there was a match for CL100017863_L01_8_1.fq.gz with reads count 72044389
# there was a match for CL100006375_L02_14_1.fq.gz with reads count 71899363
# there was a match for CL100006375_L01_7_1.fq.gz with reads count 71858548
# there was a match for CL100006375_L01_1_1.fq.gz with reads count 71769137
# there was a match for CL100017968_L01_1_1.fq.gz with reads count 71501872
# there was a match for CL100017863_L01_6_1.fq.gz with reads count 70635256
# there was a match for CL100013749_L02_5_1.fq.gz with reads count 70574912
# there was a match for CL100013751_L02_3_1.fq.gz with reads count 70523781
# there was a match for CL100013751_L02_8_1.fq.gz with reads count 70397126
# there was a match for CL100006210_L01_8_1.fq.gz with reads count 69540530
# there was a match for CL100006375_L01_5_1.fq.gz with reads count 69271527
# there was a match for CL100013751_L01_14_1.fq.gz with reads count 69223942
# there was a match for CL100013689_L01_13_1.fq.gz with reads count 68204821
# there was a match for CL100017863_L01_4_1.fq.gz with reads count 68100787
# there was a match for CL100006210_L02_11_1.fq.gz with reads count 67759374
# there was a match for CL100006210_L01_1_1.fq.gz with reads count 67256563
# there was a match for CL100017863_L02_9_1.fq.gz with reads count 66968735
# there was a match for CL100013749_L02_4_1.fq.gz with reads count 66693519
# there was a match for CL100017863_L01_3_1.fq.gz with reads count 66632623
# there was a match for CL100006375_L01_4_1.fq.gz with reads count 66539565
# there was a match for CL100006375_L02_10_1.fq.gz with reads count 66429537
# there was a match for CL100013749_L01_10_1.fq.gz with reads count 66121016
# there was a match for CL100013749_L01_13_1.fq.gz with reads count 65615156
# there was a match for CL100017968_L01_4_1.fq.gz with reads count 65258783
# there was a match for CL100006258_L01_7_1.fq.gz with reads count 65209302
# there was a match for CL100006210_L02_10_1.fq.gz with reads count 65179627
# there was a match for CL100013751_L01_10_1.fq.gz with reads count 65066529
# there was a match for CL100006210_L02_9_1.fq.gz with reads count 64743018
# there was a match for CL100013749_L02_3_1.fq.gz with reads count 64717317
# there was a match for CL100006375_L02_12_1.fq.gz with reads count 64459518
# there was a match for CL100006210_L01_4_1.fq.gz with reads count 64398744
# there was a match for CL100013749_L01_12_1.fq.gz with reads count 64019978
# there was a match for CL100006210_L02_14_1.fq.gz with reads count 63614106
# there was a match for CL100006375_L01_3_1.fq.gz with reads count 62665530
# there was a match for CL100006210_L01_3_1.fq.gz with reads count 62584862
# there was a match for CL100006210_L01_2_1.fq.gz with reads count 62496502
# there was a match for CL100013749_L02_6_1.fq.gz with reads count 62400084
# there was a match for CL100017863_L02_10_1.fq.gz with reads count 62214880
# there was a match for CL100013751_L01_12_1.fq.gz with reads count 62025335
# there was a match for CL100006258_L02_11_1.fq.gz with reads count 61557917
# there was a match for CL100006210_L02_16_1.fq.gz with reads count 61389838
# there was a match for CL100006258_L02_9_1.fq.gz with reads count 61069056
# there was a match for CL100017863_L02_13_1.fq.gz with reads count 60114680
# there was a match for CL100006375_L01_2_1.fq.gz with reads count 59803212
# there was a match for CL100006258_L02_13_1.fq.gz with reads count 58868431
# there was a match for CL100006258_L02_15_1.fq.gz with reads count 58665047
# there was a match for CL100006210_L02_15_1.fq.gz with reads count 58076757
# there was a match for CL100006258_L01_1_1.fq.gz with reads count 57544461
# there was a match for CL100006258_L01_5_1.fq.gz with reads count 57453943
# there was a match for CL100006210_L02_12_1.fq.gz with reads count 55747891
# there was a match for CL100006375_L01_6_1.fq.gz with reads count 55714611
# there was a match for CL100013689_L01_10_1.fq.gz with reads count 55243521
# there was a match for CL100006258_L01_2_1.fq.gz with reads count 55141990
# there was a match for CL100006258_L01_8_1.fq.gz with reads count 54487954
# there was a match for CL100006210_L02_13_1.fq.gz with reads count 52842620
# there was a match for CL100013689_L01_12_1.fq.gz with reads count 52392111
# there was a match for CL100006258_L01_4_1.fq.gz with reads count 52260645
# there was a match for CL100006258_L02_10_1.fq.gz with reads count 51921768
# there was a match for CL100006258_L01_6_1.fq.gz with reads count 51621902
# there was a match for CL100006258_L02_12_1.fq.gz with reads count 49656249
# there was a match for CL100006258_L02_14_1.fq.gz with reads count 49039154
# there was a match for CL100006258_L01_3_1.fq.gz with reads count 48272923

# %% [markdown]
# The counts received using the command: for x in CL100*/*_1.fq.gz; do unpigz -p 8 -c $x | wc -l && echo $x; done
# gave us counts that matches the raw reads.
#
# creating a dict to connect sample and run ids.

# %%
sample_dict = dict(zip((original_info['#Rawreads']/2).astype(int),original_info['Sample']))

# %%
sample_dict
# Out:
# {132637966: 'F1606-058',
#  130535322: 'F1604-045',
#  129543242: 'F1604-007',
#  123201286: 'F1605-009',
#  122034446: 'F1604-022',
#  120616851: 'F1513-133',
#  120486254: 'F1606-023',
#  117762934: 'F1604-009',
#  117005415: 'F1604-042',
#  113763987: 'F1602-078',
#  111842531: 'F1602-081',
#  111400205: 'F1604-032',
#  110353625: 'F1606-031',
#  109653891: 'F1602-076',
#  109549289: 'F1604-008',
#  108252248: 'F1513-080',
#  105834859: 'F1602-118',
#  104453935: 'F1513-039',
#  104423695: 'F1606-033',
#  103904714: 'F1602_007',
#  103815173: 'F1608-022',
#  103643611: 'F1604-015',
#  103579359: 'F1605-001',
#  103099179: 'F1604-036',
#  101948351: 'F1606-045',
#  101275103: 'F1513-070',
#  100597886: 'F1513-130',
#  100133592: 'F1606_024',
#  99861406: 'F1606_019',
#  98771882: 'F1608-024',
#  98728656: 'F1605-008',
#  98276715: 'F1513-194',
#  98196243: 'F1513-140',
#  97884938: 'F1606-029',
#  97861926: 'F1513_069',
#  97841735: 'F1513-179',
#  97540979: 'F1604-001',
#  96262446: 'F1602-092',
#  95741762: 'F1605-012',
#  95346953: 'F1605-043',
#  94802359: 'F1605-013',
#  94463646: 'F1513-059',
#  94274630: 'F1513-020',
#  93975400: 'F1605-010',
#  93050452: 'F1513-002',
#  92987408: 'F1606-003',
#  92694651: 'F1606-051',
#  91561148: 'F1513-200',
#  91393769: 'F1602_013',
#  91337159: 'F1606_017',
#  91074617: 'F1604-044',
#  90911643: 'F1606-053',
#  90849163: 'F1606-036',
#  90835032: 'F1606-059',
#  90148678: 'F1606-021',
#  89833031: 'F1602-111',
#  89446284: 'F1604-014',
#  89261324: 'F1513-193',
#  89252417: 'F1604-010',
#  89101256: 'F1608-025',
#  89012832: 'F1513-115',
#  88950737: 'F1513_147',
#  88818427: 'F1608-028',
#  88683007: 'F1513-014',
#  88503752: 'F1513-036',
#  88296375: 'F1513-060',
#  88150637: 'F1602-105',
#  88108973: 'F1513-068',
#  88098203: 'F1513-120',
#  88028503: 'F1606-039',
#  87970482: 'F1513-156',
#  87780353: 'F1513-105',
#  87716842: 'F1605-042',
#  87562969: 'F1606_011',
#  87247125: 'F1513-093',
#  87040501: 'F1606-056',
#  86939817: 'F1602-085',
#  86871175: 'F1608_008',
#  86788219: 'F1606_020',
#  86554789: 'F1513-005',
#  86208537: 'F1513-015',
#  86036439: 'F1513-112',
#  85799126: 'F1608-015',
#  85680626: 'F1604-031',
#  85625444: 'F1513-113',
#  85405471: 'F1513-003',
#  85379381: 'F1513-111',
#  85226660: 'F1602-119',
#  85191318: 'F1513-088',
#  85046754: 'F1513_189',
#  84997874: 'F1602-025',
#  84988461: 'F1513-004',
#  84789672: 'F1513-208',
#  84761248: 'F1513_108',
#  84654410: 'F1606-032',
#  84288711: 'F1606-005',
#  84006586: 'F1608_004',
#  83833923: 'F1602-048',
#  83747847: 'F1513-037',
#  83567754: 'F1513-107',
#  83530597: 'F1602-091',
#  83484590: 'F1602-077',
#  83413396: 'F1513-176',
#  83158462: 'F1513-038',
#  83122662: 'F1602-080',
#  83018615: 'F1513-034',
#  82981061: 'F1605-035',
#  82970853: 'F1605-040',
#  82882879: 'F1605-044',
#  82599075: 'F1513-012',
#  82530431: 'F1606_052',
#  82441957: 'F1513_047',
#  82309961: 'F1513_057',
#  82215284: 'F1602-009',
#  82193601: 'F1604_012_1',
#  82164910: 'F1604-011',
#  81996155: 'F1513-075',
#  81967251: 'F1606_040',
#  81799240: 'F1513-011',
#  81486763: 'F1602-100',
#  81223201: 'F1513-092',
#  81091240: 'F1513_074',
#  81072913: 'F1513-169',
#  81030800: 'F1606-013',
#  81027337: 'F1606-047',
#  81007797: 'F1513_159',
#  81003026: 'F1604_012_2',
#  80915600: 'F1513-087',
#  80862044: 'F1513-137',
#  80820121: 'F1513_116',
#  80753088: 'F1608-027',
#  80736488: 'F1608-026',
#  80574372: 'F1602-112',
#  80469586: 'F1513-132',
#  80248510: 'F1513-049',
#  80138996: 'F1606-048',
#  80108990: 'F1606_002',
#  79881759: 'F1513-199',
#  79840237: 'F1513-058',
#  79832620: 'F1606-041',
#  79809355: 'F1513_131',
#  79374636: 'F1606-008',
#  79323570: 'F1513-095',
#  79212052: 'F1513-010',
#  79030710: 'F1513-017',
#  78960503: 'F1513-157',
#  78956459: 'F1606-007',
#  78884592: 'F1606-038',
#  78557350: 'F1602-079',
#  78539860: 'F1513-109',
#  78359755: 'F1513_152',
#  77934141: 'F1606-022',
#  77908289: 'F1513-067',
#  77820058: 'F1513-138',
#  77597823: 'F1608_023',
#  77503048: 'F1513-050',
#  77420817: 'F1602-014',
#  76733122: 'F1513-040',
#  76724581: 'F1605-003',
#  76673481: 'F1513-191',
#  76642625: 'F1513-008',
#  76500556: 'F1606-046',
#  76405215: 'F1606-042',
#  76135640: 'F1513-114',
#  76033774: 'F1513-198',
#  76015836: 'F1602-021',
#  75997916: 'F1606-055',
#  75988063: 'F1606_006',
#  75473807: 'F1513-195',
#  75346943: 'F1604_012_3',
#  75296377: 'F1513-016',
#  75287628: 'F1606_035',
#  75252277: 'F1602_107',
#  75235909: 'F1606-034',
#  74745368: 'F1606-030',
#  74729657: 'F1606-015',
#  74593399: 'F1513-077',
#  74516614: 'F1604_030',
#  74486731: 'F1513-192',
#  74352388: 'F1602-117',
#  74306499: 'F1606-050',
#  74124591: 'F1513-033',
#  74106569: 'F1513-207',
#  74052720: 'F1513-217',
#  73942094: 'F1513-079',
#  73914100: 'F1605_032',
#  73879091: 'F1602-101',
#  73504092: 'F1513_172',
#  73482488: 'F1602-068',
#  73455178: 'F1513-013',
#  72881398: 'F1513_171',
#  72875061: 'F1513-122',
#  72822596: 'F1605-033',
#  72616930: 'F1608-018',
#  72587542: 'F1513-190',
#  72556309: 'F1513-196',
#  72549916: 'F1513_139',
#  72295951: 'F1513-009',
#  72214402: 'F1513-153',
#  72163553: 'F1602-060',
#  72117278: 'F1606-028',
#  72044389: 'F1513-158',
#  71899363: 'F1606_027',
#  71896488: 'F1606-049',
#  71858548: 'F1606_043',
#  71769137: 'F1605_004',
#  71565134: 'F1602-042',
#  71501872: 'F1602-005',
#  71319153: 'F1606-004',
#  71210091: 'F1513-121',
#  70635256: 'F1513-154',
#  70574912: 'F1602_040',
#  70523781: 'F1513_110',
#  70397126: 'F1513_151',
#  70050736: 'F1513-222',
#  69810902: 'F1605-031',
#  69540530: 'F1604_012_4',
#  69469214: 'F1513-123',
#  69310362: 'F1513-094',
#  69271527: 'F1606_018',
#  69223942: 'F1513_048',
#  69175833: 'F1602-058',
#  68735696: 'F1604-017',
#  68292511: 'F1606-001',
#  68227878: 'F1513-018',
#  68204821: 'F1513_170',
#  68100787: 'F1513-146',
#  68026216: 'F1602-031',
#  68004885: 'F1513-085',
#  67896266: 'F1513-145',
#  67759374: 'F1605_005_3',
#  67598566: 'F1605-045',
#  67469425: 'F1608-021',
#  67414455: 'F1602-046',
#  67366903: 'F1513-035',
#  67256563: 'F1602_022_1',
#  67109577: 'F1602-062',
#  66968735: 'F1513-161',
#  66933403: 'F1608-029',
#  66693519: 'F1602_033',
#  66632623: 'F1513-144',
#  66594097: 'F1513-086',
#  66539565: 'F1606_016',
#  66429537: 'F1608_007',
#  66148433: 'F1513-081',
#  66121016: 'F1602_008',
#  65872074: 'F1513-220',
#  65747454: 'F1602-041',
#  65693785: 'F1602-093',
#  65615156: 'F1608_006',
#  65565798: 'F1606-026',
#  65544823: 'F1602-023',
#  65276858: 'F1513-106',
#  65258783: 'F1608-002',
#  65209302: 'F1602_061',
#  65179627: 'F1605_005_2',
#  65066529: 'F1602_099',
#  65040260: 'F1606-054',
#  64743018: 'F1605_005_1',
#  64717317: 'F1608_010',
#  64694337: 'F1513-210',
#  64486978: 'F1606-060',
#  64459518: 'F1606_014',
#  64398744: 'F1602_022_4',
#  64287678: 'F1606-044',
#  64151479: 'F1602-004',
#  64117742: 'F1602-113',
#  64019978: 'F1602_015',
#  63834540: 'F1513-224',
#  63614106: 'F1606_025_6',
#  63052184: 'F1602-086',
#  62721741: 'F1602-024',
#  62665530: 'F1606_012',
#  62608802: 'F1513-209',
#  62584862: 'F1602_022_3',
#  62496502: 'F1602_022_2',
#  62400084: 'F1602_047',
#  62214880: 'F1513-162',
#  62214458: 'F1608-009',
#  62025335: 'F1513_019',
#  61557917: 'F1602_027',
#  61389838: 'F1606_025_8',
#  61069056: 'F1602_006',
#  61037908: 'F1602-069',
#  60334366: 'F1513-076',
#  60114680: 'F1513-178',
#  59803212: 'F1606_010',
#  59270359: 'F1608-003',
#  59133855: 'F1606-057',
#  58868431: 'F1602_063',
#  58665047: 'F1602_106',
#  58593410: 'F1605-041',
#  58469094: 'F1606-009',
#  58275014: 'F1602-067',
#  58076757: 'F1606_025_7',
#  57631237: 'F1605-036',
#  57544461: 'F1608_001_1',
#  57453943: 'F1602_020',
#  57241874: 'F1513-221',
#  56787795: 'F1513-001',
#  55812964: 'F1513-197',
#  55747891: 'F1605_005_4',
#  55714611: 'F1604_033',
#  55243521: 'F1513_155',
#  55141990: 'F1608_001_2',
#  54824383: 'F1513-006',
#  54712786: 'F1513-177',
#  54487954: 'F1602_087',
#  53295607: 'F1513-223',
#  53060676: 'F1513-218',
#  52842620: 'F1606_025_5',
#  52392111: 'F1513_160',
#  52260645: 'F1608_001_4',
#  51921768: 'F1602_019',
#  51753809: 'F1606-037',
#  51621902: 'F1602_026',
#  51458348: 'F1513-219',
#  49656249: 'F1602_059',
#  49039154: 'F1604_039',
#  48272923: 'F1608_001_3',
#  21361099: 'F1513-078'}

# %%
def combine_readcount_with_ID(ID_reads, folder_reads):
    unmatched_samples = []
    for key, value in folder_reads.items():
        if value in ID_reads:
            ID_reads[value] = [ID_reads[value], key]
        else:
            print(value, ' was not present as read count in the samples list')
            unmatched_samples.append(key)
    return ID_reads, unmatched_samples

# %%
combined_ids, unmatched_samples = combine_readcount_with_ID(sample_dict, CountMethod2_dict)

# %%
unmatched_samples
# Out:
# []

# %%
ids_df = pd.DataFrame.from_dict(combined_ids, orient='index')

unmatched_samples = []
id_pairs = []
for sample_id in ids_df[0]:
    if type(sample_id) == str:
        unmatched_samples.append(sample_id)
    else: 
        id_pairs.append(sample_id)

# %%
id_pairs
# Out:
# [['F1604-007', 'CL100017968_L01_2_1.fq.gz'],
#  ['F1602_007', 'CL100013749_L01_9_1.fq.gz'],
#  ['F1606_024', 'CL100013749_L02_7_1.fq.gz'],
#  ['F1606_019', 'CL100013749_L02_1_1.fq.gz'],
#  ['F1513-140', 'CL100017863_L01_2_1.fq.gz'],
#  ['F1513_069', 'CL100013751_L01_16_1.fq.gz'],
#  ['F1602_013', 'CL100013749_L01_11_1.fq.gz'],
#  ['F1606_017', 'CL100013749_L01_16_1.fq.gz'],
#  ['F1513_147', 'CL100013751_L02_7_1.fq.gz'],
#  ['F1606_011', 'CL100013749_L01_15_1.fq.gz'],
#  ['F1608_008', 'CL100013749_L02_2_1.fq.gz'],
#  ['F1606_020', 'CL100006375_L02_13_1.fq.gz'],
#  ['F1513_189', 'CL100013689_L01_16_1.fq.gz'],
#  ['F1513_108', 'CL100013751_L02_2_1.fq.gz'],
#  ['F1608_004', 'CL100006375_L02_9_1.fq.gz'],
#  ['F1513-176', 'CL100017863_L02_12_1.fq.gz'],
#  ['F1606_052', 'CL100013751_L01_9_1.fq.gz'],
#  ['F1513_047', 'CL100013751_L01_13_1.fq.gz'],
#  ['F1513_057', 'CL100013751_L01_15_1.fq.gz'],
#  ['F1604_012_1', 'CL100006210_L01_5_1.fq.gz'],
#  ['F1606_040', 'CL100006375_L02_16_1.fq.gz'],
#  ['F1513_074', 'CL100013751_L02_1_1.fq.gz'],
#  ['F1513-169', 'CL100017863_L02_11_1.fq.gz'],
#  ['F1513_159', 'CL100013689_L01_11_1.fq.gz'],
#  ['F1604_012_2', 'CL100006210_L01_6_1.fq.gz'],
#  ['F1513_116', 'CL100013751_L02_4_1.fq.gz'],
#  ['F1606_002', 'CL100006375_L02_11_1.fq.gz'],
#  ['F1513-199', 'CL100017863_L02_15_1.fq.gz'],
#  ['F1513_131', 'CL100013751_L02_5_1.fq.gz'],
#  ['F1513-157', 'CL100017863_L01_7_1.fq.gz'],
#  ['F1513-138', 'CL100017863_L01_1_1.fq.gz'],
#  ['F1608_023', 'CL100013751_L01_11_1.fq.gz'],
#  ['F1602-014', 'CL100017968_L01_3_1.fq.gz'],
#  ['F1606_006', 'CL100013749_L01_14_1.fq.gz'],
#  ['F1604_012_3', 'CL100006210_L01_7_1.fq.gz'],
#  ['F1606_035', 'CL100006375_L02_15_1.fq.gz'],
#  ['F1602_107', 'CL100006258_L02_16_1.fq.gz'],
#  ['F1604_030', 'CL100013749_L02_8_1.fq.gz'],
#  ['F1513-192', 'CL100017863_L02_14_1.fq.gz'],
#  ['F1513-207', 'CL100017863_L02_16_1.fq.gz'],
#  ['F1605_032', 'CL100006375_L01_8_1.fq.gz'],
#  ['F1513_172', 'CL100013689_L01_15_1.fq.gz'],
#  ['F1513_171', 'CL100013689_L01_14_1.fq.gz'],
#  ['F1513_139', 'CL100013751_L02_6_1.fq.gz'],
#  ['F1513-153', 'CL100017863_L01_5_1.fq.gz'],
#  ['F1513-158', 'CL100017863_L01_8_1.fq.gz'],
#  ['F1606_027', 'CL100006375_L02_14_1.fq.gz'],
#  ['F1606_043', 'CL100006375_L01_7_1.fq.gz'],
#  ['F1605_004', 'CL100006375_L01_1_1.fq.gz'],
#  ['F1602-005', 'CL100017968_L01_1_1.fq.gz'],
#  ['F1513-154', 'CL100017863_L01_6_1.fq.gz'],
#  ['F1602_040', 'CL100013749_L02_5_1.fq.gz'],
#  ['F1513_110', 'CL100013751_L02_3_1.fq.gz'],
#  ['F1513_151', 'CL100013751_L02_8_1.fq.gz'],
#  ['F1604_012_4', 'CL100006210_L01_8_1.fq.gz'],
#  ['F1606_018', 'CL100006375_L01_5_1.fq.gz'],
#  ['F1513_048', 'CL100013751_L01_14_1.fq.gz'],
#  ['F1513_170', 'CL100013689_L01_13_1.fq.gz'],
#  ['F1513-146', 'CL100017863_L01_4_1.fq.gz'],
#  ['F1605_005_3', 'CL100006210_L02_11_1.fq.gz'],
#  ['F1602_022_1', 'CL100006210_L01_1_1.fq.gz'],
#  ['F1513-161', 'CL100017863_L02_9_1.fq.gz'],
#  ['F1602_033', 'CL100013749_L02_4_1.fq.gz'],
#  ['F1513-144', 'CL100017863_L01_3_1.fq.gz'],
#  ['F1606_016', 'CL100006375_L01_4_1.fq.gz'],
#  ['F1608_007', 'CL100006375_L02_10_1.fq.gz'],
#  ['F1602_008', 'CL100013749_L01_10_1.fq.gz'],
#  ['F1608_006', 'CL100013749_L01_13_1.fq.gz'],
#  ['F1608-002', 'CL100017968_L01_4_1.fq.gz'],
#  ['F1602_061', 'CL100006258_L01_7_1.fq.gz'],
#  ['F1605_005_2', 'CL100006210_L02_10_1.fq.gz'],
#  ['F1602_099', 'CL100013751_L01_10_1.fq.gz'],
#  ['F1605_005_1', 'CL100006210_L02_9_1.fq.gz'],
#  ['F1608_010', 'CL100013749_L02_3_1.fq.gz'],
#  ['F1606_014', 'CL100006375_L02_12_1.fq.gz'],
#  ['F1602_022_4', 'CL100006210_L01_4_1.fq.gz'],
#  ['F1602_015', 'CL100013749_L01_12_1.fq.gz'],
#  ['F1606_025_6', 'CL100006210_L02_14_1.fq.gz'],
#  ['F1606_012', 'CL100006375_L01_3_1.fq.gz'],
#  ['F1602_022_3', 'CL100006210_L01_3_1.fq.gz'],
#  ['F1602_022_2', 'CL100006210_L01_2_1.fq.gz'],
#  ['F1602_047', 'CL100013749_L02_6_1.fq.gz'],
#  ['F1513-162', 'CL100017863_L02_10_1.fq.gz'],
#  ['F1513_019', 'CL100013751_L01_12_1.fq.gz'],
#  ['F1602_027', 'CL100006258_L02_11_1.fq.gz'],
#  ['F1606_025_8', 'CL100006210_L02_16_1.fq.gz'],
#  ['F1602_006', 'CL100006258_L02_9_1.fq.gz'],
#  ['F1513-178', 'CL100017863_L02_13_1.fq.gz'],
#  ['F1606_010', 'CL100006375_L01_2_1.fq.gz'],
#  ['F1602_063', 'CL100006258_L02_13_1.fq.gz'],
#  ['F1602_106', 'CL100006258_L02_15_1.fq.gz'],
#  ['F1606_025_7', 'CL100006210_L02_15_1.fq.gz'],
#  ['F1608_001_1', 'CL100006258_L01_1_1.fq.gz'],
#  ['F1602_020', 'CL100006258_L01_5_1.fq.gz'],
#  ['F1605_005_4', 'CL100006210_L02_12_1.fq.gz'],
#  ['F1604_033', 'CL100006375_L01_6_1.fq.gz'],
#  ['F1513_155', 'CL100013689_L01_10_1.fq.gz'],
#  ['F1608_001_2', 'CL100006258_L01_2_1.fq.gz'],
#  ['F1602_087', 'CL100006258_L01_8_1.fq.gz'],
#  ['F1606_025_5', 'CL100006210_L02_13_1.fq.gz'],
#  ['F1513_160', 'CL100013689_L01_12_1.fq.gz'],
#  ['F1608_001_4', 'CL100006258_L01_4_1.fq.gz'],
#  ['F1602_019', 'CL100006258_L02_10_1.fq.gz'],
#  ['F1602_026', 'CL100006258_L01_6_1.fq.gz'],
#  ['F1602_059', 'CL100006258_L02_12_1.fq.gz'],
#  ['F1604_039', 'CL100006258_L02_14_1.fq.gz'],
#  ['F1608_001_3', 'CL100006258_L01_3_1.fq.gz']]

# %%
id_translation_df = pd.DataFrame(id_pairs).rename({0:'Sample_id', 1:'run_id'}, axis=1)

# %%
id_translation_df.to_csv('3regionData/run_id_sample_id_translater.csv', index=False)

# %%
len(id_translation_df)
# Out:
# 107
