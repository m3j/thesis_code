# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sn 
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Open GTDBtk results (bac120andAr122.summary.tsv)

# %%
f = open("data56_related_files/gtdbtk.bac_ar_summary_relevant_columns.tsv", "r")
files = f.read()

# %% [markdown]
# #### Create list and dataframe

# %%
fileList = files.split("\n")

# %%
df = pd.DataFrame(fileList)

# %% [markdown]
# #### Cleaning df and splitting string to columns

# %%
df.columns = ['temp']
# user_genome	classification	fastani_reference	fastani_reference_radius	fastani_taxonomy	
# fastani_ani	fastani_af	closest_placement_reference	closest_placement_radius	closest_placement_taxonomy	
# closest_placement_ani	closest_placement_af	pplacer_taxonomy	classification_method	note	
# other_related_references(genome_id,species_name,radius,ANI,AF)	msa_percent	translation_table	red_value
# warnings

df[['user_genome','classification', 'closest_placement_taxonomy',
    'msa_percent']] = df.temp.str.split("\t",expand=True)

# %%
df.head(3)
# Out:
#                                                 temp  user_genome  \
# 0  user_genome\tclassification\tclosest_placement...  user_genome
# 1  S10C1032\td__Bacteria;p__Bacteroidota;c__Bacte...     S10C1032
# 2  S10C1039\td__Bacteria;p__Firmicutes;c__Bacilli...     S10C1039
#
#                                       classification  \
# 0                                     classification
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                           closest_placement_taxonomy  msa_percent
# 0                         closest_placement_taxonomy  msa_percent
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...        33.75
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        94.58

# %%
# drop first row because we get double headers 
df = df.drop(0)

# drop the last row since it is empty
last_row = len(df)
df = df.drop(df.index[last_row-1])

# %%
# drop first coulmn that is the original combined string
df = df.iloc[: , 1:]

# %%
# Because archea and bacteria were concatinated the header line is present further down where the archea file starts. 
df.drop(index=df[df['user_genome'] == 'user_genome'].index, inplace=True)

# %%
df
# Out:
#      user_genome                                     classification  \
# 1       S10C1032  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2       S10C1039  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 3       S10C1113  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 4        S10C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 5       S10C1295  d__Bacteria;p__Campylobacterota;c__Campylobact...
# ...          ...                                                ...
# 2378      S9C962  d__Bacteria;p__Campylobacterota;c__Campylobact...
# 2379       S9C99  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...
# 2381    S23C1277  d__Archaea;p__Methanobacteriota;c__Methanobact...
# 2382    S34C1277  d__Archaea;p__Methanobacteriota;c__Methanobact...
# 2383    S53C3468  d__Archaea;p__Methanobacteriota;c__Methanobact...
#
#                              closest_placement_taxonomy msa_percent
# 1     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       33.75
# 2     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       94.58
# 3     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       96.07
# 4     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       67.12
# 5     d__Bacteria;p__Campylobacterota;c__Campylobact...       44.93
# ...                                                 ...         ...
# 2378  d__Bacteria;p__Campylobacterota;c__Campylobact...       93.17
# 2379  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...       51.82
# 2381  d__Archaea;p__Methanobacteriota;c__Methanobact...       74.32
# 2382  d__Archaea;p__Methanobacteriota;c__Methanobact...       41.32
# 2383  d__Archaea;p__Methanobacteriota;c__Methanobact...       56.79
#
# [2382 rows x 4 columns]

# %%
#splitting classification to columns based on tax-rank
df[['Domain','Phylum', 'Class', 'Order', 'Family', 
    'Genus', 'Species']] = df.classification.str.split(";",expand=True)
#splitting user_genome ID to sample and cluster
df[['sample','cluster']] = df.user_genome.str.split("C",expand=True)

# %%
df
# Out:
#      user_genome                                     classification  \
# 1       S10C1032  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2       S10C1039  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 3       S10C1113  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 4        S10C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 5       S10C1295  d__Bacteria;p__Campylobacterota;c__Campylobact...
# ...          ...                                                ...
# 2378      S9C962  d__Bacteria;p__Campylobacterota;c__Campylobact...
# 2379       S9C99  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...
# 2381    S23C1277  d__Archaea;p__Methanobacteriota;c__Methanobact...
# 2382    S34C1277  d__Archaea;p__Methanobacteriota;c__Methanobact...
# 2383    S53C3468  d__Archaea;p__Methanobacteriota;c__Methanobact...
#
#                              closest_placement_taxonomy msa_percent  \
# 1     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       33.75
# 2     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       94.58
# 3     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       96.07
# 4     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       67.12
# 5     d__Bacteria;p__Campylobacterota;c__Campylobact...       44.93
# ...                                                 ...         ...
# 2378  d__Bacteria;p__Campylobacterota;c__Campylobact...       93.17
# 2379  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...       51.82
# 2381  d__Archaea;p__Methanobacteriota;c__Methanobact...       74.32
# 2382  d__Archaea;p__Methanobacteriota;c__Methanobact...       41.32
# 2383  d__Archaea;p__Methanobacteriota;c__Methanobact...       56.79
#
#            Domain                Phylum               Class  \
# 1     d__Bacteria       p__Bacteroidota      c__Bacteroidia
# 2     d__Bacteria         p__Firmicutes          c__Bacilli
# 3     d__Bacteria         p__Firmicutes          c__Bacilli
# 4     d__Bacteria         p__Firmicutes          c__Bacilli
# 5     d__Bacteria   p__Campylobacterota  c__Campylobacteria
# ...           ...                   ...                 ...
# 2378  d__Bacteria   p__Campylobacterota  c__Campylobacteria
# 2379  d__Bacteria       p__Firmicutes_C    c__Negativicutes
# 2381   d__Archaea  p__Methanobacteriota  c__Methanobacteria
# 2382   d__Archaea  p__Methanobacteriota  c__Methanobacteria
# 2383   d__Archaea  p__Methanobacteriota  c__Methanobacteria
#
#                       Order                  Family                     Genus  \
# 1          o__Bacteroidales       f__Bacteroidaceae            g__Phocaeicola
# 2        o__Lactobacillales     f__Lactobacillaceae    g__Limosilactobacillus
# 3        o__Lactobacillales     f__Lactobacillaceae    g__Limosilactobacillus
# 4        o__Lactobacillales     f__Lactobacillaceae              g__Weissella
# 5      o__Campylobacterales    f__Helicobacteraceae         g__Helicobacter_D
# ...                     ...                     ...                       ...
# 2378   o__Campylobacterales    f__Helicobacteraceae         g__Helicobacter_G
# 2379   o__Acidaminococcales   f__Acidaminococcaceae  g__Phascolarctobacterium
# 2381  o__Methanobacteriales  f__Methanobacteriaceae   g__Methanobrevibacter_A
# 2382  o__Methanobacteriales  f__Methanobacteriaceae   g__Methanobrevibacter_A
# 2383  o__Methanobacteriales  f__Methanobacteriaceae   g__Methanobrevibacter_A
#
#                                    Species sample cluster
# 1                     s__Phocaeicola dorei    S10    1032
# 2         s__Limosilactobacillus ingluviei    S10    1039
# 3              s__Limosilactobacillus oris    S10    1113
# 4               s__Weissella thailandensis    S10     119
# 5               s__Helicobacter_D pullorum    S10    1295
# ...                                    ...    ...     ...
# 2378                                   s__     S9     962
# 2379  s__Phascolarctobacterium sp000436095     S9      99
# 2381        s__Methanobrevibacter_A woesei    S23    1277
# 2382        s__Methanobrevibacter_A woesei    S34    1277
# 2383        s__Methanobrevibacter_A woesei    S53    3468
#
# [2382 rows x 13 columns]

# %%
df.cluster = df.cluster.astype(int)

# %% [markdown]
# #### Function to check if the bins in the same cluster has recieved the same taxonomical assignation

# %%
def CheckingIdenticalTaxInCluster(df):

    sortedByCluster = df.sort_values(by=['cluster'])
    rows = sortedByCluster.iterrows()
    _, nextRow = next(rows)  # take first item from row_iterator
    countSpecies = 0 
    countGenus = 0
    countFamily = 0
    
    for i, row in rows:
        if (ClusterValuesIsEqual(row, nextRow)): 
            if not (SpeciesNotDefined(row, nextRow)):
                if (IsdifferentSpecieces(row, nextRow)):
                    DifferenceInTaxRank(row, nextRow)
                    print('species differ')
                    countSpecies += 1
            if (SpeciesNotDefined(row, nextRow)):
                if not (GenusNotDefined(row, nextRow)):
                    if (IsdifferentGenus(row, nextRow)):
                        DifferenceInTaxRank(row, nextRow)
                        print('Genus differ')
                        countGenus += 1
                if (GenusNotDefined(row, nextRow)):
                    if (IsFamilyDifferent(row, nextRow)):
                        DifferenceInTaxRank(row, nextRow)
                        print('family differ')      
                        countFamily += 1
        nextRow = row
    
    print('number of times where species differ:', countSpecies) # can be multipe species in same cluster. 
    print('number of times where genus differ:', countGenus)
    print('number of times where family differ:', countFamily)

# %%
def ClusterValuesIsEqual(row, nextRow):
    return row['cluster'] == nextRow['cluster']

# %%
def IsdifferentSpecieces(row, nextRow):
    return row['Species'] != nextRow['Species']

# %%
def DifferenceInTaxRank(row, nextRow):
    print(row['user_genome'], row['classification'])
    print(nextRow['user_genome'], nextRow['classification'])

# %%
def SpeciesNotDefined(row, nextRow):
    return row['Species'] == 's__' or nextRow['Species'] == 's__'

# %%
def IsdifferentGenus(row, nextRow):
    return row['Genus'] != nextRow['Genus']

# %%
def GenusNotDefined(row, nextRow):
    return row['Genus'] == 'g__' or nextRow['Genus'] == 'g__'

# %%
def IsFamilyDifferent(row, nextRow):
    return row['Family'] != nextRow['Family']

# %%
CheckingIdenticalTaxInCluster(df)
# Out:
# S50C1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Barnesiellaceae;g__Barnesiella;s__
# S27C1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Coprobacteraceae;g__;s__
# family differ
# S26C1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Coprobacteraceae;g__;s__
# S50C1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Barnesiellaceae;g__Barnesiella;s__
# family differ
# S35C456 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales;f__Mycobacteriaceae;g__Corynebacterium;s__Corynebacterium xerosis
# S36C456 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales;f__Mycobacteriaceae;g__Corynebacterium;s__Corynebacterium pollutisoli
# species differ
# S50C672 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia coli_D
# S8C672 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia flexneri
# species differ
# S16C672 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia flexneri
# S50C672 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Escherichia;s__Escherichia coli_D
# species differ
# S40C1149 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__UBA2856;s__
# S26C1149 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__RUG12045;s__
# Genus differ
# S21C1149 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__RUG12045;s__
# S40C1149 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__UBA2856;s__
# Genus differ
# S21C1793 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__GCA-900066135;s__
# S31C1793 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__UMGS1375;s__
# Genus differ
# S37C2991 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Mediterraneibacter;s__
# S1C2991 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Sellimonas;s__Sellimonas sp002161525
# Genus differ
# S30C2991 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Sellimonas;s__Sellimonas sp002161525
# S37C2991 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Lachnospirales;f__Lachnospiraceae;g__Mediterraneibacter;s__
# Genus differ
# S40C3056 d__Bacteria;p__Actinobacteriota;c__Coriobacteriia;o__Coriobacteriales;f__Eggerthellaceae;g__Paraeggerthella;s__
# S47C3056 d__Bacteria;p__Actinobacteriota;c__Coriobacteriia;o__Coriobacteriales;f__Eggerthellaceae;g__Rubneribacter;s__
# Genus differ
# number of times where species differ: 3
# number of times where genus differ: 6
# number of times where family differ: 2

# %%
# Where species differ: 
df[df["cluster"] == 1]
# One cluster leads to 3 times where species differs.
# Out:
#      user_genome                                     classification  \
# 659        S26C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 727        S27C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 1543       S45C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 1868       S50C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                              closest_placement_taxonomy msa_percent  \
# 659                                                 N/A        19.0
# 727                                                 N/A       11.12
# 1543                                                N/A       10.56
# 1868  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       15.39
#
#            Domain           Phylum           Class             Order  \
# 659   d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 727   d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 1543  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 1868  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
#
#                    Family           Genus Species sample  cluster
# 659   f__Coprobacteraceae             g__     s__    S26        1
# 727   f__Coprobacteraceae             g__     s__    S27        1
# 1543  f__Coprobacteraceae             g__     s__    S45        1
# 1868   f__Barnesiellaceae  g__Barnesiella     s__    S50        1

# %% [markdown]
# Number of undefined families:

# %%
df[df["Family"] == 'f__'].count()
# Out:
# user_genome                   0
# classification                0
# closest_placement_taxonomy    0
# msa_percent                   0
# Domain                        0
# Phylum                        0
# Class                         0
# Order                         0
# Family                        0
# Genus                         0
# Species                       0
# sample                        0
# cluster                       0
# dtype: int64

# %%
df[df["Genus"] == 'g__'].count()
# Out:
# user_genome                   108
# classification                108
# closest_placement_taxonomy    108
# msa_percent                   108
# Domain                        108
# Phylum                        108
# Class                         108
# Order                         108
# Family                        108
# Genus                         108
# Species                       108
# sample                        108
# cluster                       108
# dtype: int64

# %%
df[df["Species"] == 's__'].count()
# Out:
# user_genome                   1093
# classification                1093
# closest_placement_taxonomy    1093
# msa_percent                   1093
# Domain                        1093
# Phylum                        1093
# Class                         1093
# Order                         1093
# Family                        1093
# Genus                         1093
# Species                       1093
# sample                        1093
# cluster                       1093
# dtype: int64

# %%
df.nunique()
# Out:
# user_genome                   2382
# classification                 467
# closest_placement_taxonomy     397
# msa_percent                   1786
# Domain                           2
# Phylum                          17
# Class                           21
# Order                           52
# Family                         100
# Genus                          246
# Species                        269
# sample                          56
# cluster                       1067
# dtype: int64

# %% [markdown]
# ### Overview
# Out of 2382 bins/rows
#
# * 1093 species undefined
# * 108 genus undefined
# * 0 families undefined
#
# Out of 1067 clusters
# * 3 times did species differ within two clusters
# * 6 times did genus differ within 4 different clusters
# * 2 times did families differ within the same cluster C1.

# %% [markdown]
# ### Lactobacillus/Alistipes Bins
# Generating dataframes with only Lactobacillus or Alistipes bins

# %%
Lactobacillus_df = df[df["Genus"] == 'g__Lactobacillus']
Lactobacillaceae_df =df[df["Family"] == 'f__Lactobacillaceae']

# %%
Lactobacillus_df = pd.DataFrame(Lactobacillus_df)
Lactobacillaceae_df = pd.DataFrame(Lactobacillaceae_df)

# %%
Alistipes_df = df[df["Genus"].isin(['g__Alistipes','g__Alistipes_A'])]
Alistipes_df = pd.DataFrame(Alistipes_df)

# %%
Alistipes_df
# Out:
#      user_genome                                     classification  \
# 7      S10C15900  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 34        S10C90  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 71        S11C90  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 131      S12C685  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 138       S12C90  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# ...          ...                                                ...
# 2294     S8C3336  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2319      S8C674  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2326       S8C90  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2331     S9C1094  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2336    S9C14905  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                              closest_placement_taxonomy msa_percent  \
# 7     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       95.37
# 34    d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       14.08
# 71    d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       90.49
# 131   d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       14.91
# 138   d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       20.31
# ...                                                 ...         ...
# 2294  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       13.96
# 2319  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       78.28
# 2326  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       93.15
# 2331  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       69.35
# 2336  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       93.41
#
#            Domain           Phylum           Class             Order  \
# 7     d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 34    d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 71    d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 131   d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 138   d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# ...           ...              ...             ...               ...
# 2294  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 2319  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 2326  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 2331  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 2336  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
#
#                 Family         Genus                   Species sample  cluster
# 7     f__Rikenellaceae  g__Alistipes  s__Alistipes sp000434235    S10    15900
# 34    f__Rikenellaceae  g__Alistipes  s__Alistipes sp900021155    S10       90
# 71    f__Rikenellaceae  g__Alistipes  s__Alistipes sp900021155    S11       90
# 131   f__Rikenellaceae  g__Alistipes   s__Alistipes finegoldii    S12      685
# 138   f__Rikenellaceae  g__Alistipes  s__Alistipes sp900021155    S12       90
# ...                ...           ...                       ...    ...      ...
# 2294  f__Rikenellaceae  g__Alistipes                       s__     S8     3336
# 2319  f__Rikenellaceae  g__Alistipes       s__Alistipes dispar     S8      674
# 2326  f__Rikenellaceae  g__Alistipes  s__Alistipes sp900021155     S8       90
# 2331  f__Rikenellaceae  g__Alistipes  s__Alistipes sp002161445     S9     1094
# 2336  f__Rikenellaceae  g__Alistipes  s__Alistipes sp900546065     S9    14905
#
# [99 rows x 13 columns]

# %%
Lactobacillus_df.to_csv('data56_related_files/GTDB_Lactobacillus.csv', index = False)
Alistipes_df.to_csv('data56_related_files/GTDB_Alistipes.csv', index = False)

# %%
Lactobacillaceae_df.to_csv('data56_related_files/GTDB_Lactobacillaceae.csv', index = False)

# %%
Lactobacillus_df.head(5)
# Out:
#    user_genome                                     classification  \
# 13     S10C205  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 20     S10C362  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 28     S10C569  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 49     S11C205  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 61     S11C569  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                            closest_placement_taxonomy msa_percent  \
# 13  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       84.32
# 20  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       70.24
# 28  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        95.0
# 49  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        72.6
# 61  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       84.93
#
#          Domain         Phylum       Class               Order  \
# 13  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 20  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 28  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 49  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 61  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
#
#                  Family             Genus                      Species sample  \
# 13  f__Lactobacillaceae  g__Lactobacillus   s__Lactobacillus crispatus    S10
# 20  f__Lactobacillaceae  g__Lactobacillus  s__Lactobacillus gallinarum    S10
# 28  f__Lactobacillaceae  g__Lactobacillus   s__Lactobacillus johnsonii    S10
# 49  f__Lactobacillaceae  g__Lactobacillus   s__Lactobacillus crispatus    S11
# 61  f__Lactobacillaceae  g__Lactobacillus   s__Lactobacillus johnsonii    S11
#
#     cluster
# 13      205
# 20      362
# 28      569
# 49      205
# 61      569

# %%
Lactobacillaceae_df
# Out:
#      user_genome                                     classification  \
# 2       S10C1039  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 3       S10C1113  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 4        S10C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 6       S10C1297  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 8       S10C1752  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# ...          ...                                                ...
# 2358      S9C362  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2359     S9C3913  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2361      S9C442  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2363     S9C4469  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2369      S9C569  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                              closest_placement_taxonomy msa_percent  \
# 2     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       94.58
# 3     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       96.07
# 4     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       67.12
# 6     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       93.47
# 8     d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       85.09
# ...                                                 ...         ...
# 2358  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       88.76
# 2359                                                N/A       92.44
# 2361  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       15.64
# 2363  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       18.78
# 2369  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       69.92
#
#            Domain         Phylum       Class               Order  \
# 2     d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 3     d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 4     d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 6     d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 8     d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# ...           ...            ...         ...                 ...
# 2358  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2359  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2361  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2363  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2369  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
#
#                    Family                   Genus  \
# 2     f__Lactobacillaceae  g__Limosilactobacillus
# 3     f__Lactobacillaceae  g__Limosilactobacillus
# 4     f__Lactobacillaceae            g__Weissella
# 6     f__Lactobacillaceae    g__Ligilactobacillus
# 8     f__Lactobacillaceae    g__Ligilactobacillus
# ...                   ...                     ...
# 2358  f__Lactobacillaceae        g__Lactobacillus
# 2359  f__Lactobacillaceae    g__Ligilactobacillus
# 2361  f__Lactobacillaceae  g__Limosilactobacillus
# 2363  f__Lactobacillaceae    g__Ligilactobacillus
# 2369  f__Lactobacillaceae        g__Lactobacillus
#
#                                Species sample  cluster
# 2     s__Limosilactobacillus ingluviei    S10     1039
# 3          s__Limosilactobacillus oris    S10     1113
# 4           s__Weissella thailandensis    S10      119
# 6          s__Ligilactobacillus agilis    S10     1297
# 8      s__Ligilactobacillus salivarius    S10     1752
# ...                                ...    ...      ...
# 2358       s__Lactobacillus gallinarum     S9      362
# 2359                               s__     S9     3913
# 2361  s__Limosilactobacillus reuteri_E     S9      442
# 2363     s__Ligilactobacillus aviarius     S9     4469
# 2369        s__Lactobacillus johnsonii     S9      569
#
# [344 rows x 13 columns]
