# %% [markdown]
# ## Bin Plot with Quality and examination of replicate type relation to bin quality
#
#
# This notebook examins the following:
# - join of quality with taxonomy and general statistics on bin quality.
# - visualization of bin quality on all bins and Lactobacillaceae bins.
# - examination of replicate types impact on number of bins.
# - examination of replicate types impact on bin quality.
# - linear regression of relation between number of bins and sample size.
# - examination of bins not annotated with GTDB

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import ranksums

# %% [markdown]
# ##### Open quality df produced by CheckM_plot.ipynb and the GTDB df's from GTDB_SanityCheck.ipynb

# %%
#Small datasets of 56 samples
df_quality = pd.read_csv('../data56_related_files/Contamination_completness_df.csv')
df_all = pd.read_csv('../data56_related_files/GTDB_All.csv')
df_Lactobacillaceae = pd.read_csv('../data56_related_files/GTDB_Lactobacillaceae.csv')

# %%
#rename key to get identical in all datasets
df_all = df_all.rename({'user_genome': 'Bin_Id'}, axis=1)
df_Lactobacillaceae = df_Lactobacillaceae.rename({'user_genome': 'Bin_Id'}, axis=1)
df_quality = df_quality.rename({'Bin Id': 'Bin_Id'}, axis=1)

# %%
df_Lactobacillaceae.head(5)
# Out:
#     Bin_Id                                     classification  \
# 0  S45C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 1  S25C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2  S49C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 3  S39C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 4   S8C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                           closest_placement_taxonomy  msa_percent  \
# 0  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        40.00
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        73.26
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        53.94
# 3  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        65.52
# 4  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        77.29
#
#         Domain         Phylum       Class               Order  \
# 0  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 1  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 3  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 4  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
#
#                 Family                   Genus                     Species  \
# 0  f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 1  f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 2  f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 3  f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 4  f__Lactobacillaceae            g__Weissella  s__Weissella thailandensis
#
#   sample  cluster
# 0    S45      105
# 1    S25      105
# 2    S49      105
# 3    S39      105
# 4     S8      119

# %%
df_quality.head(5)
# Out:
#       Bin_Id               Marker lineage  # genomes  # markers  \
# 0  S10C10200                  root (UID1)       5656         56
# 1   S10C1032   o__Bacteroidales (UID2654)        163        486
# 2   S10C1039  o__Lactobacillales (UID355)        490        334
# 3   S10C1094         k__Bacteria (UID203)       5449        104
# 4  S10C10947                  root (UID1)       5656         56
#
#    # marker sets    0    1  2  3  4  5+  Completeness  Contamination  \
# 0             24   56    0  0  0  0   0          0.00           0.00
# 1            266  298  186  2  0  0   0         38.94           0.38
# 2            183    3  331  0  0  0   0         98.91           0.00
# 3             58   92   12  0  0  0   0         14.66           0.00
# 4             24   56    0  0  0  0   0          0.00           0.00
#
#    Strain heterogeneity  bin_class  class_3
# 0                   0.0          3        2
# 1                   0.0          3        2
# 2                   0.0          0        0
# 3                   0.0          3        2
# 4                   0.0          3        2

# %% [markdown]
# #### Joining quality with taxonomy
# Left join to add the quality to the tax df

# %%
df_Lactobacillaceae_Q = df_Lactobacillaceae.join(df_quality.set_index('Bin_Id'), on='Bin_Id')

# %%
df_all_Q = df_all.join(df_quality.set_index('Bin_Id'), on='Bin_Id')

# %%
df_Lactobacillaceae_Q.head(5)
# Out:
#     Bin_Id                                     classification  \
# 0  S45C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 1  S25C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2  S49C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 3  S39C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 4   S8C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                           closest_placement_taxonomy  msa_percent  \
# 0  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        40.00
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        73.26
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        53.94
# 3  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        65.52
# 4  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        77.29
#
#         Domain         Phylum       Class               Order  \
# 0  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 1  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 3  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 4  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
#
#                 Family                   Genus  ...    1   2  3  4  5+  \
# 0  f__Lactobacillaceae  g__Limosilactobacillus  ...  147   0  0  0   0
# 1  f__Lactobacillaceae  g__Limosilactobacillus  ...  280   3  0  0   0
# 2  f__Lactobacillaceae  g__Limosilactobacillus  ...  221   2  0  0   0
# 3  f__Lactobacillaceae  g__Limosilactobacillus  ...  249   4  0  0   0
# 4  f__Lactobacillaceae            g__Weissella  ...  264  13  1  0   0
#
#    Completeness  Contamination  Strain heterogeneity  bin_class  class_3
# 0         44.55           0.00                  0.00          3        2
# 1         86.50           0.96                 66.67          1        1
# 2         67.92           0.04                100.00          1        1
# 3         82.29           1.82                 25.00          1        1
# 4         75.10           6.25                 93.75          2        1
#
# [5 rows x 28 columns]

# %%
df_all_Q['cluster'].head(5)
# Out:
# 0    1032
# 1    1039
# 2    1113
# 3     119
# 4    1295
# Name: cluster, dtype: int64

# %% [markdown]
# ### General statistics on quality

# %%
df_quality.groupby('class_3').count()
# Out:
#          Bin_Id  Marker lineage  # genomes  # markers  # marker sets     0  \
# class_3
# 0           609             609        609        609            609   609
# 1           755             755        755        755            755   755
# 2          1601            1601       1601       1601           1601  1601
#
#             1     2     3     4    5+  Completeness  Contamination  \
# class_3
# 0         609   609   609   609   609           609            609
# 1         755   755   755   755   755           755            755
# 2        1601  1601  1601  1601  1601          1601           1601
#
#          Strain heterogeneity  bin_class
# class_3
# 0                         609        609
# 1                         755        755
# 2                        1601       1601

# %%
df_all_Q['Completeness'].describe()
# Out:
# count    2382.000000
# mean       60.131335
# std        31.357057
# min         0.000000
# 25%        29.332500
# 50%        65.090000
# 75%        91.167500
# max       100.000000
# Name: Completeness, dtype: float64

# %%
df_all_Q['Contamination'].describe()
# Out:
# count    2382.000000
# mean        1.731956
# std         9.282143
# min         0.000000
# 25%         0.000000
# 50%         0.315000
# 75%         1.227500
# max       265.690000
# Name: Contamination, dtype: float64

# %% [markdown]
# ### Bin class distribution and plots of both Lactobacillaceae

# %%
def drawScatter(axes, df, palette, yticks=np.arange(0, 101, 25)):
    sns.scatterplot(ax=axes[0],
                    data = df,
                    x = df.Completeness, 
                    y = df.Contamination, 
                    hue = df.class_3,
                    palette = palette,
                    legend = False)

    axes[0].set_xlabel('CheckM Completeness score', fontsize=18)
    axes[0].set_ylabel('CheckM Contamination score', fontsize=18)
    axes[0].set_xticks(np.arange(0, 101, 25))
    axes[0].set_yticks(yticks)
    axes[0].tick_params(axis='x', labelsize=16 )
    axes[0].tick_params(axis='y', labelsize=16 )

# %%
def drawHist(axes, df, palette):
    histplt = sns.histplot(ax = axes[1],
                data = df, 
                x = "class_3", 
                hue = "class_3",
                alpha = 0.7,
                bins = 3,
                palette = palette,
                legend = False)
    axes[1].set_xlabel('')
    axes[1].set_ylabel('Bin count', fontsize=18)
    axes[1].set_xticks([0.35,1,1.7])
    plt.yticks(fontsize=16)
    axes[1].set_xticklabels(labels = ['compl. >90% \n cont. <5%', 
                                      'compl. ≥50% \n cont. <10%', 
                                      'compl. <50% \n cont. ≥10%'], fontsize=14)
    #adding numbers on top of bars. 
#     for rect in axes[1].patches:
#         height = rect.get_height()
#         axes[1].annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
#                     xytext=(0, 5), textcoords='offset points', ha='center')

# %%
def drawLegend(fig, palette, nrOfclasses):
    if (nrOfclasses == 2):
        medium = Patch(color=palette[1], label='Medium High Quality')
        high = Patch(color=palette[0], label='High Quality')
   
        fig.legend( 
            handles=[medium, high],
            loc = 'center', 
            bbox_to_anchor = (0.5, -0.08),
            ncol = nrOfclasses, 
            fontsize = 16,
            frameon = False)
    
    if (nrOfclasses == 3):
        low = Patch(color=palette[2], label='Low Quality')
        medium = Patch(color=palette[1], label='Medium High Quality')
        high = Patch(color=palette[0], label='High Quality')

        fig.legend( 
            handles=[low, medium, high],
            loc = 'center', 
            bbox_to_anchor = (0.5, -0.08),
            ncol = nrOfclasses, 
            fontsize = 16,
            frameon = False)

    if (nrOfclasses == 4):
        low = Patch(color=palette[3], label='Low Quality')
        mediumHigh = Patch(color=palette[1], label='Medium High Quality \n  SQ > 50')
        mediumLow = Patch(color=palette[2], label='Medium Low Quality \n  SQ < 50')
        high = Patch(color=palette[0], label='High Quality')
    
        fig.legend( 
            handles=[low, mediumLow, mediumHigh, high],
            loc = 'center', 
            bbox_to_anchor = (0.5, -0.08),
            ncol = nrOfclasses, 
            fontsize = 16,
            frameon = False)

# %%
def setPalette(paletteName):
    return sns.color_palette(paletteName, 4)

# %%
def subplot_binQ (df1, df2, title, nrOfclasses, paletteName, yticks=np.arange(0, 101, 25)):
    fig, axes = plt.subplots(1, 2, figsize=(12,6))
#     fig.suptitle('Bin Quality ' + title, fontsize=20) 
#     plt.yticks(fontsize=16)
#     plt.xticks(fontsize=14)
    
    palette = setPalette(paletteName)
    
    drawScatter(axes, df1, paletteName, yticks)
    
    drawHist(axes, df2, paletteName)
    
    drawLegend(fig, palette, nrOfclasses)
  
    plt.tight_layout()

# %%
subplot_binQ(df_quality, df_quality, '', nrOfclasses=3, 
             paletteName="Paired", yticks = np.arange(0, 301, 50) )

plt.savefig('../resultFigs/binQuality_allbins.png',  bbox_inches='tight')

# %%
subplot_binQ(df_Lactobacillaceae_Q, df_Lactobacillaceae_Q, 'Family Lactobacillaceae (56)', 
             nrOfclasses=3, paletteName="Paired",  yticks = np.arange(0, 41, 10))
plt.savefig('../resultFigs/binQuality_lactobacillaceae.png',  bbox_inches='tight')

# %%
df_Lactobacillaceae_Q.groupby('bin_class').count()
# Out:
#            Bin_Id  classification  closest_placement_taxonomy  msa_percent  \
# bin_class
# 0             119             119                         108          119
# 1              99              99                          96           99
# 2               5               5                           5            5
# 3             121             121                         113          121
#
#            Domain  Phylum  Class  Order  Family  Genus  ...    0    1    2  \
# bin_class                                               ...
# 0             119     119    119    119     119    119  ...  119  119  119
# 1              99      99     99     99      99     99  ...   99   99   99
# 2               5       5      5      5       5      5  ...    5    5    5
# 3             121     121    121    121     121    121  ...  121  121  121
#
#              3    4   5+  Completeness  Contamination  Strain heterogeneity  \
# bin_class
# 0          119  119  119           119            119                   119
# 1           99   99   99            99             99                    99
# 2            5    5    5             5              5                     5
# 3          121  121  121           121            121                   121
#
#            class_3
# bin_class
# 0              119
# 1               99
# 2                5
# 3              121
#
# [4 rows x 27 columns]

# %% [markdown]
# ### Saving high Quality bins

# %%
df_Lactobacillaceae_Q[df_Lactobacillaceae_Q['bin_class'] == 0].to_csv(
    '../data56_related_files/HighQLactobacillaceae', index = False)

# %% [markdown]
# ### Bin quality on pooled vs individual samples

# %%
metadata = pd.read_csv('../data56_related_files/Metadata_56samples.tsv', sep='\t')

# %%
metadata.head(5)
# Out:
#   Dataset          ID Country gender age.days.                Breed  \
# 0   Huang  SRR6323134   China   male        42  Arbor Acres broiler
# 1   Huang  SRR6323252   China   male        42  Arbor Acres broiler
# 2   Huang  SRR6323384   China   male        42  Arbor Acres broiler
# 3   Huang  SRR6323414   China   male        42  Arbor Acres broiler
# 4   Huang  SRR6323550   China   male        42  Arbor Acres broiler
#
#   isolation.location     type  Feed  \
# 0              cecum  broiler  None
# 1           duodenum  broiler  None
# 2              ileum  broiler  None
# 3            jejunum  broiler  None
# 4         colorectum  broiler  None
#
#                                          Temperature  ...  \
# 0  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 1  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 2  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 3  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
# 4  reduced from 35 °C on day 1 to 24 °C on day 21...  ...
#
#                                              vaccine vægt humidity  \
# 0  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 1  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 2  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 3  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
# 4  Combined Newcastle disease virus (NDV) and inf...  NaN      NaN
#
#    sequencing.method  DNA.extraction                   Sample.replicate  \
# 0        HiSeq X Ten             NaN  pooled digesta from five chickens
# 1        HiSeq X Ten             NaN  pooled digesta from five chickens
# 2        HiSeq X Ten             NaN  pooled digesta from five chickens
# 3        HiSeq X Ten             NaN  pooled digesta from five chickens
# 4        HiSeq X Ten             NaN  pooled digesta from five chickens
#
#    location_name.farm. farm_ID G_bases avg Mbases
# 0        China:Beijing  china1     2.4        NaN
# 1        China:Beijing  china1     2.8        NaN
# 2        China:Beijing  china1     2.6        NaN
# 3        China:Beijing  china1     3.0        NaN
# 4        China:Beijing  china1     3.0        NaN
#
# [5 rows x 22 columns]

# %%
sample_index = pd.read_csv('../data56_related_files/sampleNamesIndex.txt', header = None)

# %%
sample_index.rename(columns={0: 'sampleNo', 1: 'ID'}, inplace=True)

# %%
sample_index['sampleNo'] = sample_index.sampleNo + 1

# %%
meta_sample = pd.merge(metadata, sample_index, how="inner", on='ID')

# %%
def condition_on_replicate(s):
#     'cage', 'free-range', ' conventional_broiler_house'):
    if 'pooled' in s['Sample.replicate']:
        return 'pooled'
    else:
        return 'single_replicate'

# %%
meta_sample['replicate_type'] = meta_sample.apply(condition_on_replicate, axis=1)

# %%
meta_sample.head(5)
# Out:
#   Dataset          ID Country gender age.days.                Breed  \
# 0   Huang  SRR6323134   China   male        42  Arbor Acres broiler
# 1   Huang  SRR6323252   China   male        42  Arbor Acres broiler
# 2   Huang  SRR6323384   China   male        42  Arbor Acres broiler
# 3   Huang  SRR6323414   China   male        42  Arbor Acres broiler
# 4   Huang  SRR6323550   China   male        42  Arbor Acres broiler
#
#   isolation.location     type  Feed  \
# 0              cecum  broiler  None
# 1           duodenum  broiler  None
# 2              ileum  broiler  None
# 3            jejunum  broiler  None
# 4         colorectum  broiler  None
#
#                                          Temperature  ... humidity  \
# 0  reduced from 35 °C on day 1 to 24 °C on day 21...  ...      NaN
# 1  reduced from 35 °C on day 1 to 24 °C on day 21...  ...      NaN
# 2  reduced from 35 °C on day 1 to 24 °C on day 21...  ...      NaN
# 3  reduced from 35 °C on day 1 to 24 °C on day 21...  ...      NaN
# 4  reduced from 35 °C on day 1 to 24 °C on day 21...  ...      NaN
#
#   sequencing.method DNA.extraction                   Sample.replicate  \
# 0       HiSeq X Ten            NaN  pooled digesta from five chickens
# 1       HiSeq X Ten            NaN  pooled digesta from five chickens
# 2       HiSeq X Ten            NaN  pooled digesta from five chickens
# 3       HiSeq X Ten            NaN  pooled digesta from five chickens
# 4       HiSeq X Ten            NaN  pooled digesta from five chickens
#
#    location_name.farm. farm_ID  G_bases avg Mbases sampleNo replicate_type
# 0        China:Beijing  china1      2.4        NaN       22         pooled
# 1        China:Beijing  china1      2.8        NaN       33         pooled
# 2        China:Beijing  china1      2.6        NaN       41         pooled
# 3        China:Beijing  china1      3.0        NaN       42         pooled
# 4        China:Beijing  china1      3.0        NaN       50         pooled
#
# [5 rows x 24 columns]

# %%
df_quality[['sampleNo', 'binNo']]=df_quality['Bin_Id'].str.split('C', expand=True)

# %%
df_quality['sampleNo'] = df_quality['sampleNo'].map(lambda x: x.lstrip('S')).astype(int)

# %%
meta_replicate = meta_sample[['sampleNo', 'replicate_type', 'G_bases']]

# %%
quality_replicate  = df_quality.join(meta_replicate.set_index('sampleNo'), on='sampleNo')

# %%
quality_replicate['replicate_type'].unique()
# Out:
# array(['pooled', 'single_replicate'], dtype=object)

# %%
quality_replicate.groupby('replicate_type').count()
# Out:
#                   Bin_Id  Marker lineage  # genomes  # markers  # marker sets  \
# replicate_type
# pooled              1526            1526       1526       1526           1526
# single_replicate    1439            1439       1439       1439           1439
#
#                      0     1     2     3     4    5+  Completeness  \
# replicate_type
# pooled            1526  1526  1526  1526  1526  1526          1526
# single_replicate  1439  1439  1439  1439  1439  1439          1439
#
#                   Contamination  Strain heterogeneity  bin_class  class_3  \
# replicate_type
# pooled                     1526                  1526       1526     1526
# single_replicate           1439                  1439       1439     1439
#
#                   sampleNo  binNo  G_bases
# replicate_type
# pooled                1526   1526     1526
# single_replicate      1439   1439     1439

# %%
pooled = quality_replicate[quality_replicate['replicate_type']== 'pooled']
single_replicate = quality_replicate[quality_replicate['replicate_type']== 'single_replicate']

# %%
def drawcountPlot(axes, df, palette):
    
    sns.countplot(x = 'class_3', 
                  hue = 'replicate_type', 
                  data = df, 
                  palette = palette)
    
    
    axes.set_xticklabels(labels = ['High', 'Medium', 'Low'], fontsize=16)
    axes.set_ylabel('Bin count', fontsize=20)
    axes.set_xlabel('')
    plt.yticks(fontsize=20)
    
    legend_labels, _= axes.get_legend_handles_labels()
    axes.legend(legend_labels, ['Pooled','Single replicate'], 
            loc = 'center', 
            bbox_to_anchor = (0.5, -0.1),
                ncol = 3,
          title='', 
          frameon = False,
          fontsize = 20,
          title_fontsize = 22)

# %%
def subplot_binQ_histcompare (df, title, paletteName, yticks=np.arange(0, 101, 25)):
    fig, axes = plt.subplots(1, 1, figsize=(12,6))
#     fig.suptitle('Bin Quality ' + title, fontsize=20) 
#     plt.yticks(fontsize=16)
#     plt.xticks(fontsize=14)
    
    palette = setPalette(paletteName)
    
    drawcountPlot(axes, df, paletteName)
  
    plt.tight_layout()

# %%
subplot_binQ_histcompare(quality_replicate, 'title', 
             paletteName="Paired" )

plt.savefig('../resultFigs/sampletype_binQ.png', bbox_inches='tight')

# %% [markdown]
# To further understand the difference between pooled and individual samples we look into the bins after dereplication to see if the number of bins are replicates to a higher degree in any of the two groups

# %%
df_dereplicated_bins = pd.read_csv('../data56_related_files/derepelicatedBins_dRep.tsv')

# %%
dereplicated_bins = df_dereplicated_bins['derepelicatedBins_dRep'].str.replace('.fna', '')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
drep_quality_replicate = quality_replicate[quality_replicate['Bin_Id'].isin(dereplicated_bins)]

# %%
subplot_binQ_histcompare(drep_quality_replicate, 'title', 
             paletteName="Paired" )

plt.savefig('../resultFigs/dRep_sampletype_binQ.png', bbox_inches='tight')

# %% [markdown]
# ### Count of bins with pooled/single replicates in all and dereplicated bins

# %%
pooled.groupby('class_3').count()['Bin_Id']
# Out:
# class_3
# 0    347
# 1    361
# 2    818
# Name: Bin_Id, dtype: int64

# %%
single_replicate.groupby('class_3').count()['Bin_Id']
# Out:
# class_3
# 0    262
# 1    394
# 2    783
# Name: Bin_Id, dtype: int64

# %%
drep_pooled = pooled[pooled['Bin_Id'].isin(dereplicated_bins)]

# %%
drep_single_replicate = single_replicate[single_replicate['Bin_Id'].isin(dereplicated_bins)]

# %%
drep_single_replicate.groupby('bin_class').count()['Bin_Id']
# Out:
# bin_class
# 0    161
# 1    218
# 2     34
# 3      1
# Name: Bin_Id, dtype: int64

# %%
drep_pooled.groupby('bin_class').count()['Bin_Id']
# Out:
# bin_class
# 0    154
# 1    152
# 2     13
# Name: Bin_Id, dtype: int64

# %% [markdown]
# ### statistics on contamination and completeness on dereplicated bins

# %%
drep_quality_replicate['Contamination'].describe()
# Out:
# count    733.000000
# mean       1.137858
# std        1.375040
# min        0.000000
# 25%        0.140000
# 50%        0.790000
# 75%        1.580000
# max        9.760000
# Name: Contamination, dtype: float64

# %%
drep_quality_replicate['Completeness'].describe()
# Out:
# count    733.000000
# mean      82.502892
# std       14.984200
# min       50.000000
# 25%       70.080000
# 50%       86.500000
# 75%       95.670000
# max      100.000000
# Name: Completeness, dtype: float64

# %%
drep_quality_replicate[drep_quality_replicate['Completeness']>75].describe()['Completeness']
# Out:
# count    510.000000
# mean      91.226647
# std        7.079990
# min       75.070000
# 25%       85.447500
# 50%       93.180000
# 75%       97.535000
# max      100.000000
# Name: Completeness, dtype: float64

# %% [markdown]
# ### Replicate type impact in contamination of bins

# %%
quality_replicate.groupby('replicate_type').describe()['Contamination']
# Out:
#                    count      mean        std  min  25%  50%   75%     max
# replicate_type
# pooled            1526.0  1.392051   8.198235  0.0  0.0  0.0  0.89  181.22
# single_replicate  1439.0  1.667248  10.780067  0.0  0.0  0.0  0.99  265.69

# %%
quality_replicate.groupby('replicate_type').describe()['Completeness']
# Out:
#                    count       mean        std  min    25%     50%      75%  \
# replicate_type
# pooled            1526.0  49.217674  37.355958  0.0  12.07  46.295  89.3125
# single_replicate  1439.0  48.945170  34.595466  0.0  16.07  45.870  84.6200
#
#                     max
# replicate_type
# pooled            100.0
# single_replicate  100.0

# %%
sns.boxplot(quality_replicate['Contamination'], 
            quality_replicate['replicate_type'], palette="Paired")
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)
plt.ylabel('')
plt.xlabel('Contamination', fontsize=18)

# plt.savefig('resultFigs/rep_type_contam.png',  bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Contamination')

# %%
sns.histplot(x=quality_replicate[quality_replicate['Contamination']<6]['Contamination'], hue=quality_replicate['replicate_type'], binwidth=0.8)
# Out:
# <AxesSubplot:xlabel='Contamination', ylabel='Count'>

# %%
max(quality_replicate['Contamination'])
# Out:
# 265.69

# %%
ranksums(pooled['Contamination'], single_replicate['Contamination'])
# Out:
# RanksumsResult(statistic=-1.2319537804332081, pvalue=0.21796634993222663)

# %%
ranksums(pooled['Completeness'], single_replicate['Completeness'])
# Out:
# RanksumsResult(statistic=0.02472406458066018, pvalue=0.9802750601860636)

# %%
ranksums(pooled['G_bases'], single_replicate['G_bases'])
# Out:
# RanksumsResult(statistic=28.437417339176157, pvalue=6.973129892222755e-178)

# %%
sns.boxplot(quality_replicate['G_bases'], 
            quality_replicate['replicate_type'], palette="Paired")
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)
plt.ylabel('')
plt.xlabel('Gbases', fontsize=18)
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Gbases')

# %% [markdown]
# ### Correlation with bin quality and base counts
# Testing if there is a correlation between the number of G bases in each sample and the quality of bins

# %%
quality_replicate.head(4)
# Out:
#       Bin_Id               Marker lineage  # genomes  # markers  \
# 0  S10C10200                  root (UID1)       5656         56
# 1   S10C1032   o__Bacteroidales (UID2654)        163        486
# 2   S10C1039  o__Lactobacillales (UID355)        490        334
# 3   S10C1094         k__Bacteria (UID203)       5449        104
#
#    # marker sets    0    1  2  3  4  5+  Completeness  Contamination  \
# 0             24   56    0  0  0  0   0          0.00           0.00
# 1            266  298  186  2  0  0   0         38.94           0.38
# 2            183    3  331  0  0  0   0         98.91           0.00
# 3             58   92   12  0  0  0   0         14.66           0.00
#
#    Strain heterogeneity  bin_class  class_3  sampleNo  binNo replicate_type  \
# 0                   0.0          3        2        10  10200         pooled
# 1                   0.0          3        2        10   1032         pooled
# 2                   0.0          0        0        10   1039         pooled
# 3                   0.0          3        2        10   1094         pooled
#
#    G_bases
# 0     11.7
# 1     11.7
# 2     11.7
# 3     11.7

# %%
samples_with_quality_count = pd.DataFrame(quality_replicate.groupby('sampleNo').count()['class_3']).reset_index()

# %%
samples_with_quality_count.head()
# Out:
#    sampleNo  class_3
# 0         1       76
# 1         2       23
# 2         3       80
# 3         4       96
# 4         5       31

# %%
replicate_vs_bin = meta_replicate.join(samples_with_quality_count.set_index('sampleNo'), on='sampleNo')

# %%
replicate_vs_bin.head()
# Out:
#    sampleNo replicate_type  G_bases  class_3
# 0        22         pooled      2.4       46
# 1        33         pooled      2.8       18
# 2        41         pooled      2.6       14
# 3        42         pooled      3.0       14
# 4        50         pooled      3.0       59

# %%
m, b = np.polyfit(replicate_vs_bin['G_bases'], replicate_vs_bin['class_3'], 1)
m
# Out:
# 1.2154082805538486

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6))
sns.scatterplot(data = replicate_vs_bin, x='G_bases', 
            y='class_3', hue='replicate_type', palette='Paired', s=100)

# ax.set_xticklabels(labels = ['Pooled', 'Single Replicate'], fontsize=16)
ax.set_ylabel('Bin count', fontsize=20)
ax.set_xlabel('G bases', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)

plt.plot(replicate_vs_bin['G_bases'], m*replicate_vs_bin['G_bases'] + b, 'black', label='Fitted line')

legend_labels, _= ax.get_legend_handles_labels()
ax.legend(legend_labels, ['Fitted line','Pooled','Single replicate'], 
    loc = 'upper right', 
    bbox_to_anchor = (1.36, 0.99),
    title='', 
    fontsize = 20,
    title_fontsize = 22)


plt.savefig('../resultFigs/bases_vs_bins_count',  bbox_inches='tight')

# %% [markdown]
# #### looking at the HQ bins and the relation to bases

# %%
HQquality_replicate = quality_replicate[quality_replicate['class_3']==0]

# %%
samples_with_HQ_count = pd.DataFrame(HQquality_replicate.groupby('sampleNo').count()['class_3']).reset_index()

# %%
HQreplicate_vs_bin = meta_replicate.join(samples_with_HQ_count.set_index('sampleNo'), on='sampleNo')

# %%
HQreplicate_vs_bin.head()
# Out:
#    sampleNo replicate_type  G_bases  class_3
# 0        22         pooled      2.4        8
# 1        33         pooled      2.8        3
# 2        41         pooled      2.6        2
# 3        42         pooled      3.0        5
# 4        50         pooled      3.0        5

# %%
(HQ_m, HQ_b), what, how, this, that = np.polyfit(HQreplicate_vs_bin['G_bases'], HQreplicate_vs_bin['class_3'], 1, full=True)
HQ_m
# Out:
# 0.44215786465647805

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6))
sns.scatterplot(data = HQreplicate_vs_bin, x='G_bases', 
            y='class_3', hue='replicate_type', palette='Paired', s=100)

# ax.set_xticklabels(labels = ['Pooled', 'Single Replicate'], fontsize=16)
ax.set_ylabel('Bin count', fontsize=20)
ax.set_xlabel('G bases', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)

plt.plot(HQreplicate_vs_bin['G_bases'], HQ_m*HQreplicate_vs_bin['G_bases'] + HQ_b, 'black', label='Fitted line')

legend_labels, _= ax.get_legend_handles_labels()
ax.legend(legend_labels, ['Fitted line','Pooled','Single replicate'], 
    loc = 'upper right', 
    bbox_to_anchor = (1.36, 0.99),
    title='', 
    fontsize = 20,
    title_fontsize = 22)

plt.savefig('../resultFigs/bases_vs_HQbins_count',  bbox_inches='tight')

# %% [markdown]
# Both looking at all bins and only the high quality bins there is a correlation with the number of bins found and the amount of bases in the sample.

# %% [markdown]
# ### Missing bins - from vamb to GTDB

# %%
vamb_bins = set(quality_replicate['Bin_Id'])

# %%
GTDB_bins = set(df_all_Q['Bin_Id'])

# %%
print(len(vamb_bins))
print(len(GTDB_bins))
# Out:
# 2965
# 2382

# %%
missing_bins = vamb_bins - GTDB_bins

# %%
for bin in missing_bins:
    print(quality_replicate[quality_replicate['Bin_Id'] == bin]['Completeness'], bin)
# Out:
# 1524    0.0
# Name: Completeness, dtype: float64 S37C2652
# 2709    0.0
# Name: Completeness, dtype: float64 S6C4310
# 531    6.9
# Name: Completeness, dtype: float64 S1C1776
# 2647    0.0
# Name: Completeness, dtype: float64 S5C1006
# 2283    0.16
# Name: Completeness, dtype: float64 S4C60209
# 2512    4.17
# Name: Completeness, dtype: float64 S53C2690
# 1575    4.17
# Name: Completeness, dtype: float64 S38C2063
# 59    4.17
# Name: Completeness, dtype: float64 S11C15552
# 0    0.0
# Name: Completeness, dtype: float64 S10C10200
# 2116    16.38
# Name: Completeness, dtype: float64 S47C612
# 2885    0.16
# Name: Completeness, dtype: float64 S8C6666
# 982    8.33
# Name: Completeness, dtype: float64 S27C3361
# 2634    0.0
# Name: Completeness, dtype: float64 S56C284
# 2762    4.17
# Name: Completeness, dtype: float64 S7C28127
# 1605    11.21
# Name: Completeness, dtype: float64 S38C345
# 314    0.0
# Name: Completeness, dtype: float64 S15C3082
# 2101    12.07
# Name: Completeness, dtype: float64 S47C3539
# 2488    2.63
# Name: Completeness, dtype: float64 S53C1908
# 2881    0.16
# Name: Completeness, dtype: float64 S8C6096
# 963    4.17
# Name: Completeness, dtype: float64 S27C2088
# 2601    0.0
# Name: Completeness, dtype: float64 S55C1748
# 2122    4.17
# Name: Completeness, dtype: float64 S47C736
# 1587    0.0
# Name: Completeness, dtype: float64 S38C2781
# 523    11.21
# Name: Completeness, dtype: float64 S1C1454
# 307    0.0
# Name: Completeness, dtype: float64 S15C2603
# 1053    10.53
# Name: Completeness, dtype: float64 S28C644
# 2319    0.0
# Name: Completeness, dtype: float64 S50C215
# 2462    0.0
# Name: Completeness, dtype: float64 S52C284
# 2895    0.0
# Name: Completeness, dtype: float64 S8C7617
# 2699    8.62
# Name: Completeness, dtype: float64 S6C2499
# 2528    11.99
# Name: Completeness, dtype: float64 S53C3487
# 1626    11.21
# Name: Completeness, dtype: float64 S38C9079
# 199    0.0
# Name: Completeness, dtype: float64 S13C2716
# 1679    0.0
# Name: Completeness, dtype: float64 S3C2402
# 3    14.66
# Name: Completeness, dtype: float64 S10C1094
# 113    12.07
# Name: Completeness, dtype: float64 S12C1652
# 300    4.17
# Name: Completeness, dtype: float64 S15C22174
# 1035    8.62
# Name: Completeness, dtype: float64 S28C2610
# 2054    7.52
# Name: Completeness, dtype: float64 S46C736
# 2803    99.66
# Name: Completeness, dtype: float64 S8C1094
# 27    1.04
# Name: Completeness, dtype: float64 S10C346
# 2284    0.0
# Name: Completeness, dtype: float64 S4C6169
# 1885    10.45
# Name: Completeness, dtype: float64 S44C2991
# 560    0.0
# Name: Completeness, dtype: float64 S1C4313
# 462    0.0
# Name: Completeness, dtype: float64 S18C6208
# 2126    0.0
# Name: Completeness, dtype: float64 S47C7908
# 461    4.17
# Name: Completeness, dtype: float64 S18C6190
# 78    4.17
# Name: Completeness, dtype: float64 S11C389
# 408    0.0
# Name: Completeness, dtype: float64 S17C2991
# 280    0.0
# Name: Completeness, dtype: float64 S14C8340
# 2763    0.0
# Name: Completeness, dtype: float64 S7C2982
# 1386    5.17
# Name: Completeness, dtype: float64 S35C107
# 2546    13.79
# Name: Completeness, dtype: float64 S53C4668
# 2359    4.17
# Name: Completeness, dtype: float64 S51C1094
# 1277    0.0
# Name: Completeness, dtype: float64 S32C51539
# 2249    0.0
# Name: Completeness, dtype: float64 S4C330
# 728    10.53
# Name: Completeness, dtype: float64 S22C2227
# 1711    0.16
# Name: Completeness, dtype: float64 S3C5254
# 2553    0.0
# Name: Completeness, dtype: float64 S53C5674
# 905    0.0
# Name: Completeness, dtype: float64 S26C3726
# 1342    3.45
# Name: Completeness, dtype: float64 S34C2094
# 292    0.0
# Name: Completeness, dtype: float64 S15C17583
# 1849    0.0
# Name: Completeness, dtype: float64 S44C10117
# 1818    4.17
# Name: Completeness, dtype: float64 S43C1416
# 217    15.52
# Name: Completeness, dtype: float64 S13C468
# 510    0.0
# Name: Completeness, dtype: float64 S19C685
# 2719    6.9
# Name: Completeness, dtype: float64 S6C5559
# 404    0.0
# Name: Completeness, dtype: float64 S17C23615
# 967    0.0
# Name: Completeness, dtype: float64 S27C2384
# 1468    0.0
# Name: Completeness, dtype: float64 S36C1619
# 1639    0.0
# Name: Completeness, dtype: float64 S39C2561
# 191    0.16
# Name: Completeness, dtype: float64 S13C161509
# 343    10.5
# Name: Completeness, dtype: float64 S15C9391
# 479    3.45
# Name: Completeness, dtype: float64 S19C1829
# 450    2.04
# Name: Completeness, dtype: float64 S18C3398
# 684    0.0
# Name: Completeness, dtype: float64 S21C2652
# 1961    0.0
# Name: Completeness, dtype: float64 S45C2882
# 1674    0.0
# Name: Completeness, dtype: float64 S3C2208
# 610    8.62
# Name: Completeness, dtype: float64 S20C2177
# 1874    8.62
# Name: Completeness, dtype: float64 S44C2190
# 2426    5.17
# Name: Completeness, dtype: float64 S51C5256
# 2299    12.07
# Name: Completeness, dtype: float64 S50C121
# 1391    0.0
# Name: Completeness, dtype: float64 S35C1195
# 1586    4.17
# Name: Completeness, dtype: float64 S38C2731
# 2516    10.5
# Name: Completeness, dtype: float64 S53C2868
# 2365    16.38
# Name: Completeness, dtype: float64 S51C1516
# 786    0.0
# Name: Completeness, dtype: float64 S23C2425
# 2360    0.0
# Name: Completeness, dtype: float64 S51C1134
# 2804    4.17
# Name: Completeness, dtype: float64 S8C1162
# 2674    6.74
# Name: Completeness, dtype: float64 S5C743
# 39    3.61
# Name: Completeness, dtype: float64 S10C468
# 1203    7.47
# Name: Completeness, dtype: float64 S31C2397
# 431    0.0
# Name: Completeness, dtype: float64 S17C8522
# 2295    0.31
# Name: Completeness, dtype: float64 S4C983
# 1274    0.0
# Name: Completeness, dtype: float64 S32C4923
# 1084    8.62
# Name: Completeness, dtype: float64 S29C2437
# 1557    12.07
# Name: Completeness, dtype: float64 S38C1741
# 1422    12.07
# Name: Completeness, dtype: float64 S35C2536
# 576    11.21
# Name: Completeness, dtype: float64 S1C708
# 308    0.0
# Name: Completeness, dtype: float64 S15C2620
# 935    4.39
# Name: Completeness, dtype: float64 S27C1149
# 2838    0.0
# Name: Completeness, dtype: float64 S8C23396
# 1079    8.62
# Name: Completeness, dtype: float64 S29C2120
# 2541    0.0
# Name: Completeness, dtype: float64 S53C4143
# 396    0.0
# Name: Completeness, dtype: float64 S17C1938
# 2919    4.17
# Name: Completeness, dtype: float64 S9C20700
# 1093    0.0
# Name: Completeness, dtype: float64 S29C3986
# 348    0.0
# Name: Completeness, dtype: float64 S16C12074
# 2250    4.17
# Name: Completeness, dtype: float64 S4C341
# 1507    0.0
# Name: Completeness, dtype: float64 S37C1290
# 1466    0.0
# Name: Completeness, dtype: float64 S36C13429
# 221    0.0
# Name: Completeness, dtype: float64 S13C5141
# 218    12.07
# Name: Completeness, dtype: float64 S13C4690
# 2228    0.0
# Name: Completeness, dtype: float64 S4C2402
# 2291    0.0
# Name: Completeness, dtype: float64 S4C7280
# 2590    4.17
# Name: Completeness, dtype: float64 S54C4502
# 699    0.0
# Name: Completeness, dtype: float64 S21C4908
# 9    0.0
# Name: Completeness, dtype: float64 S10C13511
# 2436    4.17
# Name: Completeness, dtype: float64 S51C7370
# 1548    9.57
# Name: Completeness, dtype: float64 S38C1425
# 2239    2.76
# Name: Completeness, dtype: float64 S4C2736
# 1701    0.0
# Name: Completeness, dtype: float64 S3C4231
# 2385    8.93
# Name: Completeness, dtype: float64 S51C2088
# 2321    13.56
# Name: Completeness, dtype: float64 S50C24
# 1227    2.63
# Name: Completeness, dtype: float64 S31C766
# 4    0.0
# Name: Completeness, dtype: float64 S10C10947
# 2774    4.17
# Name: Completeness, dtype: float64 S7C387
# 96    4.17
# Name: Completeness, dtype: float64 S11C8538
# 1677    0.0
# Name: Completeness, dtype: float64 S3C2294
# 2896    5.17
# Name: Completeness, dtype: float64 S8C802
# 2613    0.0
# Name: Completeness, dtype: float64 S55C346
# 2693    0.0
# Name: Completeness, dtype: float64 S6C2129
# 2215    0.0
# Name: Completeness, dtype: float64 S4C2030
# 2447    0.0
# Name: Completeness, dtype: float64 S52C1157
# 2374    5.33
# Name: Completeness, dtype: float64 S51C1816
# 1740    11.61
# Name: Completeness, dtype: float64 S40C2170
# 2530    0.0
# Name: Completeness, dtype: float64 S53C3532
# 2773    6.9
# Name: Completeness, dtype: float64 S7C3681
# 1700    0.0
# Name: Completeness, dtype: float64 S3C4177
# 1694    0.0
# Name: Completeness, dtype: float64 S3C341
# 527    0.16
# Name: Completeness, dtype: float64 S1C16753
# 498    0.0
# Name: Completeness, dtype: float64 S19C4287
# 2550    0.0
# Name: Completeness, dtype: float64 S53C4986
# 2828    0.0
# Name: Completeness, dtype: float64 S8C1975
# 920    0.0
# Name: Completeness, dtype: float64 S26C6658
# 919    5.02
# Name: Completeness, dtype: float64 S26C64
# 311    11.03
# Name: Completeness, dtype: float64 S15C2868
# 1604    0.0
# Name: Completeness, dtype: float64 S38C3444
# 1911    4.17
# Name: Completeness, dtype: float64 S44C6717
# 2266    0.0
# Name: Completeness, dtype: float64 S4C4177
# 842    7.68
# Name: Completeness, dtype: float64 S25C351
# 784    6.9
# Name: Completeness, dtype: float64 S23C2226
# 1606    0.0
# Name: Completeness, dtype: float64 S38C3593
# 142    98.28
# Name: Completeness, dtype: float64 S12C3084
# 1688    0.0
# Name: Completeness, dtype: float64 S3C30847
# 534    0.0
# Name: Completeness, dtype: float64 S1C1859
# 1660    5.36
# Name: Completeness, dtype: float64 S3C1770
# 582    0.0
# Name: Completeness, dtype: float64 S1C7627
# 1496    0.0
# Name: Completeness, dtype: float64 S36C5758
# 1613    0.0
# Name: Completeness, dtype: float64 S38C4717
# 2863    0.0
# Name: Completeness, dtype: float64 S8C43
# 227    0.0
# Name: Completeness, dtype: float64 S13C5913
# 2271    7.24
# Name: Completeness, dtype: float64 S4C4834
# 1039    0.0
# Name: Completeness, dtype: float64 S28C2770
# 620    0.0
# Name: Completeness, dtype: float64 S20C3266
# 2729    0.0
# Name: Completeness, dtype: float64 S6C7200
# 2620    17.4
# Name: Completeness, dtype: float64 S55C589
# 2874    8.62
# Name: Completeness, dtype: float64 S8C5260
# 137    0.16
# Name: Completeness, dtype: float64 S12C27744
# 1638    12.07
# Name: Completeness, dtype: float64 S39C2235
# 289    0.0
# Name: Completeness, dtype: float64 S15C12588
# 1843    8.33
# Name: Completeness, dtype: float64 S43C64
# 2438    6.9
# Name: Completeness, dtype: float64 S51C8309
# 636    0.0
# Name: Completeness, dtype: float64 S20C6371
# 712    15.52
# Name: Completeness, dtype: float64 S22C1032
# 1027    0.0
# Name: Completeness, dtype: float64 S28C215
# 1756    0.0
# Name: Completeness, dtype: float64 S40C4060
# 2524    0.16
# Name: Completeness, dtype: float64 S53C3362
# 579    0.0
# Name: Completeness, dtype: float64 S1C7383
# 1889    0.0
# Name: Completeness, dtype: float64 S44C3416
# 2887    0.0
# Name: Completeness, dtype: float64 S8C6730
# 2345    5.17
# Name: Completeness, dtype: float64 S50C5481
# 1306    4.17
# Name: Completeness, dtype: float64 S33C6996
# 2572    0.0
# Name: Completeness, dtype: float64 S54C205
# 28    0.0
# Name: Completeness, dtype: float64 S10C3578
# 160    0.31
# Name: Completeness, dtype: float64 S12C4980
# 2558    2.09
# Name: Completeness, dtype: float64 S53C8005
# 2557    1.1
# Name: Completeness, dtype: float64 S53C7415
# 411    0.0
# Name: Completeness, dtype: float64 S17C341
# 60    0.0
# Name: Completeness, dtype: float64 S11C16169
# 449    0.0
# Name: Completeness, dtype: float64 S18C2628
# 1553    7.02
# Name: Completeness, dtype: float64 S38C1655
# 591    0.16
# Name: Completeness, dtype: float64 S1C97710
# 2137    4.17
# Name: Completeness, dtype: float64 S48C1816
# 198    0.0
# Name: Completeness, dtype: float64 S13C2600
# 362    0.0
# Name: Completeness, dtype: float64 S16C2854
# 106    12.63
# Name: Completeness, dtype: float64 S12C1256
# 22    0.0
# Name: Completeness, dtype: float64 S10C2784
# 1190    8.33
# Name: Completeness, dtype: float64 S31C1698
# 2007    3.11
# Name: Completeness, dtype: float64 S46C1641
# 1656    0.16
# Name: Completeness, dtype: float64 S3C150182
# 283    0.0
# Name: Completeness, dtype: float64 S14C9870
# 2731    0.0
# Name: Completeness, dtype: float64 S6C8301
# 270    0.0
# Name: Completeness, dtype: float64 S14C5788
# 2339    7.14
# Name: Completeness, dtype: float64 S50C4189
# 2514    0.0
# Name: Completeness, dtype: float64 S53C2801
# 556    0.0
# Name: Completeness, dtype: float64 S1C3853
# 435    0.0
# Name: Completeness, dtype: float64 S18C101
# 205    12.8
# Name: Completeness, dtype: float64 S13C330
# 186    0.0
# Name: Completeness, dtype: float64 S12C9322
# 34    4.17
# Name: Completeness, dtype: float64 S10C4158
# 2525    0.0
# Name: Completeness, dtype: float64 S53C3365
# 2556    4.17
# Name: Completeness, dtype: float64 S53C7347
# 2465    1.39
# Name: Completeness, dtype: float64 S52C2989
# 490    0.0
# Name: Completeness, dtype: float64 S19C341
# 1390    0.0
# Name: Completeness, dtype: float64 S35C1193
# 2951    0.0
# Name: Completeness, dtype: float64 S9C5817
# 1925    10.53
# Name: Completeness, dtype: float64 S45C1193
# 1892    0.0
# Name: Completeness, dtype: float64 S44C3648
# 2648    2.09
# Name: Completeness, dtype: float64 S5C101
# 1393    5.96
# Name: Completeness, dtype: float64 S35C12584
# 795    4.17
# Name: Completeness, dtype: float64 S23C3469
# 251    0.0
# Name: Completeness, dtype: float64 S14C2418
# 2933    0.0
# Name: Completeness, dtype: float64 S9C3225
# 550    4.17
# Name: Completeness, dtype: float64 S1C341
# 1211    10.53
# Name: Completeness, dtype: float64 S31C2991
# 1598    0.0
# Name: Completeness, dtype: float64 S38C3027
# 2635    0.0
# Name: Completeness, dtype: float64 S56C2958
# 1815    8.1
# Name: Completeness, dtype: float64 S43C1346
# 377    0.31
# Name: Completeness, dtype: float64 S16C5820
# 321    4.17
# Name: Completeness, dtype: float64 S15C341
# 2117    0.0
# Name: Completeness, dtype: float64 S47C615
# 2154    0.0
# Name: Completeness, dtype: float64 S48C32
# 1650    0.0
# Name: Completeness, dtype: float64 S3C12764
# 2337    9.65
# Name: Completeness, dtype: float64 S50C412
# 938    0.0
# Name: Completeness, dtype: float64 S27C1234
# 2038    0.0
# Name: Completeness, dtype: float64 S46C3570
# 1672    8.33
# Name: Completeness, dtype: float64 S3C2098
# 2202    0.0
# Name: Completeness, dtype: float64 S4C14225
# 180    0.0
# Name: Completeness, dtype: float64 S12C7803
# 207    4.55
# Name: Completeness, dtype: float64 S13C346
# 2469    0.93
# Name: Completeness, dtype: float64 S52C3708
# 1769    8.33
# Name: Completeness, dtype: float64 S40C64
# 1719    0.16
# Name: Completeness, dtype: float64 S3C6977
# 236    5.17
# Name: Completeness, dtype: float64 S13C9880
# 1916    0.0
# Name: Completeness, dtype: float64 S44C91
# 939    7.76
# Name: Completeness, dtype: float64 S27C1255
# 2272    0.0
# Name: Completeness, dtype: float64 S4C4910
# 1480    0.0
# Name: Completeness, dtype: float64 S36C1996
# 1534    0.0
# Name: Completeness, dtype: float64 S37C4048
# 2192    4.17
# Name: Completeness, dtype: float64 S49C2235
# 822    9.17
# Name: Completeness, dtype: float64 S24C39
# 1610    4.17
# Name: Completeness, dtype: float64 S38C4485
# 1150    12.5
# Name: Completeness, dtype: float64 S30C2226
# 1595    4.17
# Name: Completeness, dtype: float64 S38C3007
# 2193    0.0
# Name: Completeness, dtype: float64 S49C2561
# 2615    0.0
# Name: Completeness, dtype: float64 S55C4238
# 2060    4.17
# Name: Completeness, dtype: float64 S46C9528
# 457    0.0
# Name: Completeness, dtype: float64 S18C4857
# 2797    0.0
# Name: Completeness, dtype: float64 S7C8913
# 2592    0.0
# Name: Completeness, dtype: float64 S54C5571
# 399    0.0
# Name: Completeness, dtype: float64 S17C2112
# 2656    4.17
# Name: Completeness, dtype: float64 S5C18237
# 2714    0.0
# Name: Completeness, dtype: float64 S6C4645
# 1800    0.0
# Name: Completeness, dtype: float64 S42C2015
# 327    0.0
# Name: Completeness, dtype: float64 S15C4353
# 2953    12.93
# Name: Completeness, dtype: float64 S9C626
# 492    0.16
# Name: Completeness, dtype: float64 S19C35334
# 2696    0.16
# Name: Completeness, dtype: float64 S6C23475
# 118    0.0
# Name: Completeness, dtype: float64 S12C18319
# 2608    3.45
# Name: Completeness, dtype: float64 S55C2662
# 1131    4.17
# Name: Completeness, dtype: float64 S2C6322
# 1707    0.0
# Name: Completeness, dtype: float64 S3C4551
# 115    6.9
# Name: Completeness, dtype: float64 S12C1714
# 84    8.33
# Name: Completeness, dtype: float64 S11C48
# 696    2.08
# Name: Completeness, dtype: float64 S21C4126
# 208    0.0
# Name: Completeness, dtype: float64 S13C356
# 526    5.17
# Name: Completeness, dtype: float64 S1C16621
# 793    4.17
# Name: Completeness, dtype: float64 S23C3124
# 1241    8.33
# Name: Completeness, dtype: float64 S32C1573
# 1651    4.17
# Name: Completeness, dtype: float64 S3C12787
# 1709    0.0
# Name: Completeness, dtype: float64 S3C4954
# 663    4.17
# Name: Completeness, dtype: float64 S21C1693
# 2529    5.17
# Name: Completeness, dtype: float64 S53C3492
# 2329    0.0
# Name: Completeness, dtype: float64 S50C3060
# 2554    12.07
# Name: Completeness, dtype: float64 S53C5817
# 2044    0.0
# Name: Completeness, dtype: float64 S46C439
# 2293    0.0
# Name: Completeness, dtype: float64 S4C8942
# 1842    7.47
# Name: Completeness, dtype: float64 S43C528
# 1383    0.0
# Name: Completeness, dtype: float64 S34C9505
# 646    8.33
# Name: Completeness, dtype: float64 S20C8359
# 2174    1.75
# Name: Completeness, dtype: float64 S48C735
# 662    3.51
# Name: Completeness, dtype: float64 S21C1655
# 2685    0.0
# Name: Completeness, dtype: float64 S6C11797
# 2622    0.0
# Name: Completeness, dtype: float64 S55C5959
# 622    0.0
# Name: Completeness, dtype: float64 S20C3330
# 447    0.0
# Name: Completeness, dtype: float64 S18C2402
# 601    0.0
# Name: Completeness, dtype: float64 S20C16054
# 1142    10.21
# Name: Completeness, dtype: float64 S30C1415
# 856    8.33
# Name: Completeness, dtype: float64 S26C122
# 718    10.66
# Name: Completeness, dtype: float64 S22C1515
# 1749    0.0
# Name: Completeness, dtype: float64 S40C2991
# 1908    5.17
# Name: Completeness, dtype: float64 S44C6398
# 625    5.17
# Name: Completeness, dtype: float64 S20C362
# 248    0.0
# Name: Completeness, dtype: float64 S14C2239
# 495    0.0
# Name: Completeness, dtype: float64 S19C3639
# 2926    0.0
# Name: Completeness, dtype: float64 S9C2566
# 2371    10.5
# Name: Completeness, dtype: float64 S51C1744
# 1761    4.17
# Name: Completeness, dtype: float64 S40C4538
# 2422    5.17
# Name: Completeness, dtype: float64 S51C4457
# 2716    0.63
# Name: Completeness, dtype: float64 S6C4710
# 2929    5.17
# Name: Completeness, dtype: float64 S9C3039
# 2424    3.51
# Name: Completeness, dtype: float64 S51C482
# 2663    14.26
# Name: Completeness, dtype: float64 S5C356
# 2456    10.5
# Name: Completeness, dtype: float64 S52C2212
# 2659    0.0
# Name: Completeness, dtype: float64 S5C2194
# 925    11.38
# Name: Completeness, dtype: float64 S26C823
# 1602    0.0
# Name: Completeness, dtype: float64 S38C3177
# 573    0.0
# Name: Completeness, dtype: float64 S1C6399
# 1576    8.62
# Name: Completeness, dtype: float64 S38C2069
# 1585    8.33
# Name: Completeness, dtype: float64 S38C2715
# 1335    9.25
# Name: Completeness, dtype: float64 S34C1784
# 1918    11.61
# Name: Completeness, dtype: float64 S44C9950
# 2868    8.62
# Name: Completeness, dtype: float64 S8C4731
# 2718    8.62
# Name: Completeness, dtype: float64 S6C517
# 2355    5.17
# Name: Completeness, dtype: float64 S51C1
# 69    7.93
# Name: Completeness, dtype: float64 S11C2228
# 2087    0.0
# Name: Completeness, dtype: float64 S47C2231
# 2755    1.72
# Name: Completeness, dtype: float64 S7C2175
# 35    0.0
# Name: Completeness, dtype: float64 S10C4178
# 139    0.0
# Name: Completeness, dtype: float64 S12C2881
# 660    7.76
# Name: Completeness, dtype: float64 S21C1496
# 2700    0.0
# Name: Completeness, dtype: float64 S6C2508
# 2254    2.04
# Name: Completeness, dtype: float64 S4C3545
# 594    0.0
# Name: Completeness, dtype: float64 S20C1113
# 1510    0.0
# Name: Completeness, dtype: float64 S37C1429
# 540    5.17
# Name: Completeness, dtype: float64 S1C2177
# 2394    9.48
# Name: Completeness, dtype: float64 S51C2465
# 370    4.17
# Name: Completeness, dtype: float64 S16C389
# 992    4.17
# Name: Completeness, dtype: float64 S27C468
# 2163    8.77
# Name: Completeness, dtype: float64 S48C4410
# 2744    0.0
# Name: Completeness, dtype: float64 S7C14220
# 489    0.0
# Name: Completeness, dtype: float64 S19C3219
# 611    0.0
# Name: Completeness, dtype: float64 S20C2291
# 1280    9.31
# Name: Completeness, dtype: float64 S32C5507
# 1064    0.0
# Name: Completeness, dtype: float64 S29C1234
# 2175    0.0
# Name: Completeness, dtype: float64 S48C7447
# 1405    9.65
# Name: Completeness, dtype: float64 S35C1641
# 838    1.72
# Name: Completeness, dtype: float64 S25C2561
# 23    9.48
# Name: Completeness, dtype: float64 S10C313
# 2815    0.0
# Name: Completeness, dtype: float64 S8C16484
# 864    12.28
# Name: Completeness, dtype: float64 S26C163
# 26    0.18
# Name: Completeness, dtype: float64 S10C3391
# 82    0.0
# Name: Completeness, dtype: float64 S11C4428
# 1210    0.0
# Name: Completeness, dtype: float64 S31C2730
# 2552    9.48
# Name: Completeness, dtype: float64 S53C5484
# 1356    0.0
# Name: Completeness, dtype: float64 S34C2762
# 1463    0.0
# Name: Completeness, dtype: float64 S36C12595
# 123    0.0
# Name: Completeness, dtype: float64 S12C19842
# 1554    4.17
# Name: Completeness, dtype: float64 S38C169
# 2771    0.0
# Name: Completeness, dtype: float64 S7C3222
# 2258    20.85
# Name: Completeness, dtype: float64 S4C3695
# 2578    0.0
# Name: Completeness, dtype: float64 S54C2318
# 320    0.0
# Name: Completeness, dtype: float64 S15C3389
# 2822    4.17
# Name: Completeness, dtype: float64 S8C1801
# 2788    8.97
# Name: Completeness, dtype: float64 S7C5230
# 617    13.79
# Name: Completeness, dtype: float64 S20C2838
# 1439    6.9
# Name: Completeness, dtype: float64 S35C461
# 2047    7.02
# Name: Completeness, dtype: float64 S46C482
# 107    4.17
# Name: Completeness, dtype: float64 S12C13518
# 1863    15.52
# Name: Completeness, dtype: float64 S44C1797
# 859    9.57
# Name: Completeness, dtype: float64 S26C1359
# 2756    0.0
# Name: Completeness, dtype: float64 S7C2221
# 911    0.0
# Name: Completeness, dtype: float64 S26C461
# 2786    0.0
# Name: Completeness, dtype: float64 S7C4910
# 1004    0.0
# Name: Completeness, dtype: float64 S27C6658
# 1589    8.28
# Name: Completeness, dtype: float64 S38C2865
# 2864    0.31
# Name: Completeness, dtype: float64 S8C4397
# 2938    9.64
# Name: Completeness, dtype: float64 S9C39
# 1114    0.0
# Name: Completeness, dtype: float64 S2C11152
# 2776    0.0
# Name: Completeness, dtype: float64 S7C4256
# 1668    8.62
# Name: Completeness, dtype: float64 S3C1920
# 104    6.03
# Name: Completeness, dtype: float64 S12C1150
# 581    0.0
# Name: Completeness, dtype: float64 S1C7498
# 410    0.0
# Name: Completeness, dtype: float64 S17C32467
# 1867    4.17
# Name: Completeness, dtype: float64 S44C1870
# 2930    10.53
# Name: Completeness, dtype: float64 S9C305
# 2617    0.0
# Name: Completeness, dtype: float64 S55C4488
# 1085    0.0
# Name: Completeness, dtype: float64 S29C2500
# 2549    4.46
# Name: Completeness, dtype: float64 S53C4784
# 974    0.0
# Name: Completeness, dtype: float64 S27C2892
# 188    3.45
# Name: Completeness, dtype: float64 S13C1032
# 1590    13.79
# Name: Completeness, dtype: float64 S38C2904
# 1870    0.0
# Name: Completeness, dtype: float64 S44C1945
# 2894    0.0
# Name: Completeness, dtype: float64 S8C751
# 1764    12.07
# Name: Completeness, dtype: float64 S40C500
# 185    0.0
# Name: Completeness, dtype: float64 S12C9082
# 1484    4.17
# Name: Completeness, dtype: float64 S36C2847
# 83    0.0
# Name: Completeness, dtype: float64 S11C4698
# 2357    14.89
# Name: Completeness, dtype: float64 S51C105
# 1695    0.0
# Name: Completeness, dtype: float64 S3C346
# 915    5.17
# Name: Completeness, dtype: float64 S26C5602
# 2584    0.0
# Name: Completeness, dtype: float64 S54C2958
# 1712    5.9
# Name: Completeness, dtype: float64 S3C530
# 334    0.0
# Name: Completeness, dtype: float64 S15C6413
# 19    0.0
# Name: Completeness, dtype: float64 S10C2408
# 2544    17.24
# Name: Completeness, dtype: float64 S53C439
# 1805    0.0
# Name: Completeness, dtype: float64 S42C6996
# 213    0.0
# Name: Completeness, dtype: float64 S13C4046
# 2902    7.02
# Name: Completeness, dtype: float64 S8C931
# 473    0.0
# Name: Completeness, dtype: float64 S19C11182
# 1319    0.0
# Name: Completeness, dtype: float64 S34C1195
# 114    0.0
# Name: Completeness, dtype: float64 S12C167211
# 643    1.04
# Name: Completeness, dtype: float64 S20C723
# 2779    0.0
# Name: Completeness, dtype: float64 S7C43760
# 486    0.0
# Name: Completeness, dtype: float64 S19C2918
# 1344    8.62
# Name: Completeness, dtype: float64 S34C2155
# 502    0.0
# Name: Completeness, dtype: float64 S19C4565
# 2286    0.0
# Name: Completeness, dtype: float64 S4C6395
# 176    0.0
# Name: Completeness, dtype: float64 S12C7332
# 633    0.31
# Name: Completeness, dtype: float64 S20C54372
# 2506    11.91
# Name: Completeness, dtype: float64 S53C2510
# 2551    4.17
# Name: Completeness, dtype: float64 S53C5353
# 754    0.0
# Name: Completeness, dtype: float64 S22C848
# 1573    4.17
# Name: Completeness, dtype: float64 S38C2047
# 340    4.17
# Name: Completeness, dtype: float64 S15C7973
# 2236    5.74
# Name: Completeness, dtype: float64 S4C2709
# 1503    0.0
# Name: Completeness, dtype: float64 S36C8443
# 134    0.0
# Name: Completeness, dtype: float64 S12C2597
# 72    6.9
# Name: Completeness, dtype: float64 S11C2669
# 1224    5.17
# Name: Completeness, dtype: float64 S31C6184
# 323    4.17
# Name: Completeness, dtype: float64 S15C389
# 1835    0.0
# Name: Completeness, dtype: float64 S43C382
# 923    8.62
# Name: Completeness, dtype: float64 S26C7715
# 983    8.62
# Name: Completeness, dtype: float64 S27C345
# 551    0.0
# Name: Completeness, dtype: float64 S1C346
# 405    0.0
# Name: Completeness, dtype: float64 S17C2363
# 691    4.17
# Name: Completeness, dtype: float64 S21C3020
# 879    10.34
# Name: Completeness, dtype: float64 S26C2309
# 1767    7.14
# Name: Completeness, dtype: float64 S40C5369
# 1493    0.0
# Name: Completeness, dtype: float64 S36C4789
# 122    0.0
# Name: Completeness, dtype: float64 S12C1904
# 2383    4.17
# Name: Completeness, dtype: float64 S51C205
# 2166    0.0
# Name: Completeness, dtype: float64 S48C4635
# 1477    0.16
# Name: Completeness, dtype: float64 S36C1930
# 2268    4.17
# Name: Completeness, dtype: float64 S4C4347
# 1693    0.0
# Name: Completeness, dtype: float64 S3C3397
# 2625    0.0
# Name: Completeness, dtype: float64 S56C11884
# 287    0.0
# Name: Completeness, dtype: float64 S15C11591
# 1614    8.33
# Name: Completeness, dtype: float64 S38C48
# 1649    1.88
# Name: Completeness, dtype: float64 S3C1247
# 1904    2.68
# Name: Completeness, dtype: float64 S44C573
# 1895    0.0
# Name: Completeness, dtype: float64 S44C4048
# 1403    4.17
# Name: Completeness, dtype: float64 S35C1619
# 1148    23.21
# Name: Completeness, dtype: float64 S30C2076
# 1659    0.0
# Name: Completeness, dtype: float64 S3C1767
# 1790    0.0
# Name: Completeness, dtype: float64 S41C2950
# 589    0.0
# Name: Completeness, dtype: float64 S1C9042
# 2790    0.0
# Name: Completeness, dtype: float64 S7C5367
# 1504    0.0
# Name: Completeness, dtype: float64 S36C9254
# 902    14.58
# Name: Completeness, dtype: float64 S26C356
# 2611    4.17
# Name: Completeness, dtype: float64 S55C284
# 2251    0.31
# Name: Completeness, dtype: float64 S4C346
# 220    4.17
# Name: Completeness, dtype: float64 S13C5004
# 2280    0.0
# Name: Completeness, dtype: float64 S4C5806
# 52    12.07
# Name: Completeness, dtype: float64 S10C995
# 2445    4.17
# Name: Completeness, dtype: float64 S51C9528
# 873    10.34
# Name: Completeness, dtype: float64 S26C205
# 200    0.0
# Name: Completeness, dtype: float64 S13C27796
# 1754    8.33
# Name: Completeness, dtype: float64 S40C3478
# 2346    6.27
# Name: Completeness, dtype: float64 S50C5507
# 1214    0.0
# Name: Completeness, dtype: float64 S31C36060
# 955    6.9
# Name: Completeness, dtype: float64 S27C187
# 721    7.93
# Name: Completeness, dtype: float64 S22C1731
# 2559    9.38
# Name: Completeness, dtype: float64 S53C8126
# 1165    3.45
# Name: Completeness, dtype: float64 S30C3975
# 2230    0.0
# Name: Completeness, dtype: float64 S4C2511
# 2555    4.17
# Name: Completeness, dtype: float64 S53C6842
# 804    0.0
# Name: Completeness, dtype: float64 S23C5970
# 564    0.0
# Name: Completeness, dtype: float64 S1C4583
# 466    0.0
# Name: Completeness, dtype: float64 S18C7382
# 520    11.21
# Name: Completeness, dtype: float64 S1C1320
# 1683    4.17
# Name: Completeness, dtype: float64 S3C2722
# 602    10.34
# Name: Completeness, dtype: float64 S20C177
# 2179    6.9
# Name: Completeness, dtype: float64 S48C877
# 1182    4.17
# Name: Completeness, dtype: float64 S31C1061
# 2662    1.02
# Name: Completeness, dtype: float64 S5C346
# 318    4.17
# Name: Completeness, dtype: float64 S15C3345
# 2574    0.0
# Name: Completeness, dtype: float64 S54C2164
# 403    8.33
# Name: Completeness, dtype: float64 S17C234
# 1699    0.0
# Name: Completeness, dtype: float64 S3C4116
# 2944    0.0
# Name: Completeness, dtype: float64 S9C4550
# 2575    0.0
# Name: Completeness, dtype: float64 S54C2212
# 1336    14.11
# Name: Completeness, dtype: float64 S34C1862
# 415    4.17
# Name: Completeness, dtype: float64 S17C439
# 714    12.07
# Name: Completeness, dtype: float64 S22C105
# 2276    4.17
# Name: Completeness, dtype: float64 S4C5303
# 414    0.0
# Name: Completeness, dtype: float64 S17C4177
# 2782    13.79
# Name: Completeness, dtype: float64 S7C4552
# 2587    0.0
# Name: Completeness, dtype: float64 S54C3185
# 2570    0.0
# Name: Completeness, dtype: float64 S54C1995
# 145    1.02
# Name: Completeness, dtype: float64 S12C346
# 333    0.0
# Name: Completeness, dtype: float64 S15C5834
# 745    5.17
# Name: Completeness, dtype: float64 S22C4060
# 1787    4.17
# Name: Completeness, dtype: float64 S41C2015
# 2612    10.34
# Name: Completeness, dtype: float64 S55C309
# 2364    10.34
# Name: Completeness, dtype: float64 S51C1449
# 1678    0.0
# Name: Completeness, dtype: float64 S3C2303
# 2627    4.17
# Name: Completeness, dtype: float64 S56C1839
# 36    0.0
# Name: Completeness, dtype: float64 S10C4206
# 1715    0.31
# Name: Completeness, dtype: float64 S3C5689
# 2517    0.0
# Name: Completeness, dtype: float64 S53C3143
# 1682    5.17
# Name: Completeness, dtype: float64 S3C270
# 657    5.18
# Name: Completeness, dtype: float64 S21C1386
# 542    0.0
# Name: Completeness, dtype: float64 S1C2402
# 1346    4.17
# Name: Completeness, dtype: float64 S34C2297
# 1547    0.0
# Name: Completeness, dtype: float64 S38C1343
# 2051    11.58
# Name: Completeness, dtype: float64 S46C622
# 44    0.0
# Name: Completeness, dtype: float64 S10C6361
# 2959    0.0
# Name: Completeness, dtype: float64 S9C8555
# 2955    0.0
# Name: Completeness, dtype: float64 S9C7604
# 426    0.0
# Name: Completeness, dtype: float64 S17C6879
# 609    0.0
# Name: Completeness, dtype: float64 S20C2098
# 1455    0.0
# Name: Completeness, dtype: float64 S35C7866
# 567    0.0
# Name: Completeness, dtype: float64 S1C5120
# 1456    0.0
# Name: Completeness, dtype: float64 S35C8345
# 2482    10.34
# Name: Completeness, dtype: float64 S53C1808
# 2721    0.0
# Name: Completeness, dtype: float64 S6C5680
# 2825    12.85
# Name: Completeness, dtype: float64 S8C184
# 161    13.79
# Name: Completeness, dtype: float64 S12C51
# 874    0.0
# Name: Completeness, dtype: float64 S26C2063
# 179    6.9
# Name: Completeness, dtype: float64 S12C7570
# 1882    8.33
# Name: Completeness, dtype: float64 S44C2701
# 645    0.16
# Name: Completeness, dtype: float64 S20C81764
# 1763    4.39
# Name: Completeness, dtype: float64 S40C482
# 2892    8.33
# Name: Completeness, dtype: float64 S8C70
# 2347    7.05
# Name: Completeness, dtype: float64 S50C567
# 2219    5.17
# Name: Completeness, dtype: float64 S4C2098
# 1942    4.17
# Name: Completeness, dtype: float64 S45C1950
# 284    0.0
# Name: Completeness, dtype: float64 S15C10014
# 709    4.17
# Name: Completeness, dtype: float64 S21C790
# 351    8.62
# Name: Completeness, dtype: float64 S16C15296
# 57    2.23
# Name: Completeness, dtype: float64 S11C1247
# 325    0.0
# Name: Completeness, dtype: float64 S15C3967
# 2458    4.17
# Name: Completeness, dtype: float64 S52C2318
# 2406    12.5
# Name: Completeness, dtype: float64 S51C3056
# 102    4.17
# Name: Completeness, dtype: float64 S12C11184
# 1154    4.17
# Name: Completeness, dtype: float64 S30C2750
# 504    0.0
# Name: Completeness, dtype: float64 S19C4910
# 1657    0.16
# Name: Completeness, dtype: float64 S3C160
# 1951    0.0
# Name: Completeness, dtype: float64 S45C2262
# 1040    6.9
# Name: Completeness, dtype: float64 S28C2991
# 378    0.0
# Name: Completeness, dtype: float64 S16C6043
# 1704    0.0
# Name: Completeness, dtype: float64 S3C4369
# 2876    5.33
# Name: Completeness, dtype: float64 S8C5482
# 365    0.46
# Name: Completeness, dtype: float64 S16C32011
# 1129    4.17
# Name: Completeness, dtype: float64 S2C5303
# 2802    8.33
# Name: Completeness, dtype: float64 S8C107
# 916    0.0
# Name: Completeness, dtype: float64 S26C615
# 206    4.17
# Name: Completeness, dtype: float64 S13C341
# 2683    0.0
# Name: Completeness, dtype: float64 S6C10985
# 33    4.17
# Name: Completeness, dtype: float64 S10C40318
# 2021    10.34
# Name: Completeness, dtype: float64 S46C2248
# 797    0.0
# Name: Completeness, dtype: float64 S23C43158
# 1416    0.0
# Name: Completeness, dtype: float64 S35C232
# 2448    0.0
# Name: Completeness, dtype: float64 S52C1748
# 1197    0.0
# Name: Completeness, dtype: float64 S31C1915
# 1977    5.17
# Name: Completeness, dtype: float64 S45C458
# 1839    8.62
# Name: Completeness, dtype: float64 S43C458
# 988    14.28
# Name: Completeness, dtype: float64 S27C4137
# 1367    5.17
# Name: Completeness, dtype: float64 S34C486
# 2428    7.21
# Name: Completeness, dtype: float64 S51C5419
# 2848    0.0
# Name: Completeness, dtype: float64 S8C2880
# 1667    0.0
# Name: Completeness, dtype: float64 S3C1902
# 1127    0.0
# Name: Completeness, dtype: float64 S2C483
# 2701    3.45
# Name: Completeness, dtype: float64 S6C2528
# 1591    0.0
# Name: Completeness, dtype: float64 S38C294
# 363    4.17
# Name: Completeness, dtype: float64 S16C3128
# 736    6.9
# Name: Completeness, dtype: float64 S22C2990
# 2494    8.62
# Name: Completeness, dtype: float64 S53C2161
# 1745    12.07
# Name: Completeness, dtype: float64 S40C2615
# 2561    0.0
# Name: Completeness, dtype: float64 S53C9402
# 2333    0.0
# Name: Completeness, dtype: float64 S50C3668

# %%
quality_replicate[quality_replicate['Bin_Id'] == 'S2C205']
# Out:
#       Bin_Id             Marker lineage  # genomes  # markers  # marker sets  \
# 1118  S2C205  g__Lactobacillus (UID377)         91        430            154
#
#       0    1  2  3  4  5+  Completeness  Contamination  Strain heterogeneity  \
# 1118  9  421  0  0  0   0         96.63            0.0                   0.0
#
#       bin_class  class_3  sampleNo binNo replicate_type  G_bases
# 1118          0        0         2   205         pooled     14.1

# %% [markdown]
# ### How is the distribution between pooled and single replicates of selected bins

# %%
references = pd.read_csv('../data56_related_files/present_ref_genomes.tsv', sep='\t', header=None)

# %%
references = [ '.'.join(x.split('.')[:1]) for x in references[0] ]

# %%
len(pooled[pooled['Bin_Id'].isin(references)])
# Out:
# 24

# %%
len(single_replicate[single_replicate['Bin_Id'].isin(references)])
# Out:
# 4
