# %% [markdown]
# ## Examining the GTDB output
#
# This notebook does the following:
#
# - Checking if clusters contian multiple species, genus, or families
# - generate dataframes containing all the resulting annotations and on for only Lactobacillaceae

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sn 
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Open GTDBtk results (bac120andAr122.summary.tsv)

# %%
f = open("../data56_related_files/gtdbtk.bac_ar_summary_relevant_columns.tsv", "r")
files = f.read()

# %% [markdown]
# #### Create list and dataframe

# %%
fileList = files.split("\n")

# %%
df = pd.DataFrame(fileList)

# %%
df
# Out:
#                                                       0
# 0     user_genome\tclassification\tclosest_placement...
# 1     S10C1032\td__Bacteria;p__Bacteroidota;c__Bacte...
# 2     S10C1039\td__Bacteria;p__Firmicutes;c__Bacilli...
# 3     S10C1113\td__Bacteria;p__Firmicutes;c__Bacilli...
# 4     S10C119\td__Bacteria;p__Firmicutes;c__Bacilli;...
# ...                                                 ...
# 2380  user_genome\tclassification\tclosest_placement...
# 2381  S23C1277\td__Archaea;p__Methanobacteriota;c__M...
# 2382  S34C1277\td__Archaea;p__Methanobacteriota;c__M...
# 2383  S53C3468\td__Archaea;p__Methanobacteriota;c__M...
# 2384
#
# [2385 rows x 1 columns]

# %% [markdown]
# #### Cleaning df and splitting string to columns

# %%
df.columns = ['temp']
# user_genome	classification	fastani_reference	fastani_reference_radius	fastani_taxonomy	
# fastani_ani	fastani_af	closest_placement_reference	closest_placement_radius	closest_placement_taxonomy	
# closest_placement_ani	closest_placement_af	pplacer_taxonomy	classification_method	note	
# other_related_references(genome_id,species_name,radius,ANI,AF)	msa_percent	translation_table	red_value
# warnings

df[['user_genome','classification', 'closest_placement_taxonomy',
    'msa_percent']] = df.temp.str.split("\t",expand=True)

# %%
df.head(3)
# Out:
#                                                 temp  user_genome  \
# 0  user_genome\tclassification\tclosest_placement...  user_genome
# 1  S10C1032\td__Bacteria;p__Bacteroidota;c__Bacte...     S10C1032
# 2  S10C1039\td__Bacteria;p__Firmicutes;c__Bacilli...     S10C1039
#
#                                       classification  \
# 0                                     classification
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                           closest_placement_taxonomy  msa_percent
# 0                         closest_placement_taxonomy  msa_percent
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...        33.75
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        94.58

# %%
# drop first row because we get double headers 
df = df.drop(0)

# drop the last row since it is empty
last_row = len(df)
df = df.drop(df.index[last_row-1])

# %%
# drop first coulmn that is the original combined string
df = df.iloc[: , 1:]

# %%
# Because archea and bacteria were concatinated the header line is present further down where the archea file starts. 
df.drop(index=df[df['user_genome'] == 'user_genome'].index, inplace=True)

# %%
df.head(5)
# Out:
#   user_genome                                     classification  \
# 1    S10C1032  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2    S10C1039  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 3    S10C1113  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 4     S10C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 5    S10C1295  d__Bacteria;p__Campylobacterota;c__Campylobact...
#
#                           closest_placement_taxonomy msa_percent
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       33.75
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       94.58
# 3  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       96.07
# 4  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       67.12
# 5  d__Bacteria;p__Campylobacterota;c__Campylobact...       44.93

# %%
#splitting classification to columns based on tax-rank
df[['Domain','Phylum', 'Class', 'Order', 'Family', 
    'Genus', 'Species']] = df.classification.str.split(";",expand=True)
#splitting user_genome ID to sample and cluster
df[['sample','cluster']] = df.user_genome.str.split("C",expand=True)

# %%
df.head(5)
# Out:
#   user_genome                                     classification  \
# 1    S10C1032  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 2    S10C1039  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 3    S10C1113  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 4     S10C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 5    S10C1295  d__Bacteria;p__Campylobacterota;c__Campylobact...
#
#                           closest_placement_taxonomy msa_percent       Domain  \
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       33.75  d__Bacteria
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       94.58  d__Bacteria
# 3  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       96.07  d__Bacteria
# 4  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       67.12  d__Bacteria
# 5  d__Bacteria;p__Campylobacterota;c__Campylobact...       44.93  d__Bacteria
#
#                 Phylum               Class                 Order  \
# 1      p__Bacteroidota      c__Bacteroidia      o__Bacteroidales
# 2        p__Firmicutes          c__Bacilli    o__Lactobacillales
# 3        p__Firmicutes          c__Bacilli    o__Lactobacillales
# 4        p__Firmicutes          c__Bacilli    o__Lactobacillales
# 5  p__Campylobacterota  c__Campylobacteria  o__Campylobacterales
#
#                  Family                   Genus  \
# 1     f__Bacteroidaceae          g__Phocaeicola
# 2   f__Lactobacillaceae  g__Limosilactobacillus
# 3   f__Lactobacillaceae  g__Limosilactobacillus
# 4   f__Lactobacillaceae            g__Weissella
# 5  f__Helicobacteraceae       g__Helicobacter_D
#
#                             Species sample cluster
# 1              s__Phocaeicola dorei    S10    1032
# 2  s__Limosilactobacillus ingluviei    S10    1039
# 3       s__Limosilactobacillus oris    S10    1113
# 4        s__Weissella thailandensis    S10     119
# 5        s__Helicobacter_D pullorum    S10    1295

# %%
df.cluster = df.cluster.astype(int)

# %%
df.to_csv('../data56_related_files/GTDB_All.csv', index = False)

# %% [markdown]
# ## Sanity Check
# Check if the bins in the same cluster has recieved the same taxonomical assignation

# %%
def CheckingIdenticalTaxInCluster_all(df):
    '''
    identify clusters containing different species
    1. group by cluster
    2. identify/log unique species, where species are more than one - exclude s__
    3. if species is undefined - s__ , identify unique genus for s__, where genus are more than one
    4. if genus is undefined, identify unique family, where family are more than one'''

    df.sort_values(by=['cluster'], inplace=True)
    f = open("../data56_related_files/log_cluster_irregularities.csv", "a")
    
    grouped = df.groupby('cluster')

    for index, c in grouped:
        cluster = c['cluster'].unique()
        
        uniqueGenus = []
        uniqueFamily = []
        
        # value in cluster is unique
        uniqueSpecies = c['Species'].unique()
    
        if 's__' in uniqueSpecies:
            # check genus
            uniqueGenus = c['Genus'].unique()
            if 'g__' in uniqueGenus:
                # check family
                uniqueFamily = c['Family'].unique()


        
        if (len(uniqueSpecies) > 1 or len(uniqueGenus) > 1 or len(uniqueFamily) > 1):
            
            if (len(np.delete(uniqueSpecies, np.where(uniqueSpecies == "s__"))) < 2 and 
                len(np.delete(uniqueGenus, np.where(uniqueGenus == "g__"))) < 2 and len(uniqueFamily) < 2):
                continue
                
            # there is more than one - now log it
            f.write(f"Species: {uniqueSpecies}, Genus: {uniqueGenus}, Family: {uniqueFamily}, Cluster: {cluster} \n")
        
    f.close()
    
CheckingIdenticalTaxInCluster_all(df)

# %%
# !rm data56_related_files/log_cluster_irregularities.csv

# %%
df.loc[df['cluster'] == 1]
# Out:
#      user_genome                                     classification  \
# 727        S27C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 1868       S50C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 659        S26C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 1543       S45C1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                              closest_placement_taxonomy msa_percent  \
# 727                                                 N/A       11.12
# 1868  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...       15.39
# 659                                                 N/A        19.0
# 1543                                                N/A       10.56
#
#            Domain           Phylum           Class             Order  \
# 727   d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 1868  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 659   d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
# 1543  d__Bacteria  p__Bacteroidota  c__Bacteroidia  o__Bacteroidales
#
#                    Family           Genus Species sample  cluster
# 727   f__Coprobacteraceae             g__     s__    S27        1
# 1868   f__Barnesiellaceae  g__Barnesiella     s__    S50        1
# 659   f__Coprobacteraceae             g__     s__    S26        1
# 1543  f__Coprobacteraceae             g__     s__    S45        1

# %% [markdown]
# Number of undefined at each rank:

# %%
df[df["Species"] == 's__'].count()['user_genome']
# Out:
# 1093

# %%
df[df["Genus"] == 'g__'].count()['user_genome']
# Out:
# 108

# %%
df[df["Family"] == 'f__'].count()['user_genome']
# Out:
# 0

# %%
df.nunique()
# Out:
# user_genome                   2382
# classification                 467
# closest_placement_taxonomy     397
# msa_percent                   1786
# Domain                           2
# Phylum                          17
# Class                           21
# Order                           52
# Family                         100
# Genus                          246
# Species                        269
# sample                          56
# cluster                       1067
# dtype: int64

# %% [markdown]
# ### Overview
# Out of 2382 bins/rows
#
# * 1093 bins with species undefined
# * 108 bins with genus undefined
# * 0 bins with families undefined
#
# Out of 1067 clusters
# * 2 times did species differ in two clusters - s__Corynebacterium pollutisoli/s__Corynebacterium xerosis, and s__Escherichia flexneri/s__Escherichia coli_D in cluster 456 and 672
# * 4 times did genus differ within a cluster
# * 6 times did families differ within a cluster - in all cases the confusion was between f__Coprobacteraceae and f__Barnesiellaceae.
#
# see more in the log_clusters_irregularities file.

# %% [markdown]
# ### Creating GTDB dataframe for Lactobacillaceae bins

# %%
Lactobacillaceae_df =df[df["Family"] == 'f__Lactobacillaceae']

# %%
Lactobacillaceae_df = pd.DataFrame(Lactobacillaceae_df)

# %%
Lactobacillaceae_df.to_csv('../data56_related_files/GTDB_Lactobacillaceae.csv', index = False)

# %%
Lactobacillaceae_df.head(5)
# Out:
#      user_genome                                     classification  \
# 1545     S45C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 643      S25C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 1782     S49C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 1322     S39C105  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2250      S8C119  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                              closest_placement_taxonomy msa_percent  \
# 1545  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        40.0
# 643   d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       73.26
# 1782  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       53.94
# 1322  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       65.52
# 2250  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       77.29
#
#            Domain         Phylum       Class               Order  \
# 1545  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 643   d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 1782  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 1322  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2250  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
#
#                    Family                   Genus                     Species  \
# 1545  f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 643   f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 1782  f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 1322  f__Lactobacillaceae  g__Limosilactobacillus                         s__
# 2250  f__Lactobacillaceae            g__Weissella  s__Weissella thailandensis
#
#      sample  cluster
# 1545    S45      105
# 643     S25      105
# 1782    S49      105
# 1322    S39      105
# 2250     S8      119

# %%
Bacillus_df =df[df["Class"] == 'c__Bacilli']

# %%
Bacillus_df
# Out:
#      user_genome                                     classification  \
# 2322        S8C7  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 209        S14C7  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 1379        S3C7  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 250        S15C7  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 373       S19C39  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# ...          ...                                                ...
# 37     S11C10001  d__Bacteria;p__Firmicutes;c__Bacilli;o__RF39;f...
# 2098   S55C13176  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2173    S6C25284  d__Bacteria;p__Firmicutes;c__Bacilli;o__RF39;f...
# 231    S15C25531  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 187    S14C26133  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                              closest_placement_taxonomy msa_percent  \
# 2322  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       17.63
# 209   d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       17.17
# 1379  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        80.5
# 250   d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       69.09
# 373   d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        91.9
# ...                                                 ...         ...
# 37    d__Bacteria;p__Firmicutes;c__Bacilli;o__RF39;f...       10.86
# 2098  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       17.65
# 2173  d__Bacteria;p__Firmicutes;c__Bacilli;o__RF39;f...       16.97
# 231   d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        10.8
# 187   d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...       54.28
#
#            Domain         Phylum       Class               Order  \
# 2322  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 209   d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 1379  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 250   d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 373   d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# ...           ...            ...         ...                 ...
# 37    d__Bacteria  p__Firmicutes  c__Bacilli             o__RF39
# 2098  d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 2173  d__Bacteria  p__Firmicutes  c__Bacilli             o__RF39
# 231   d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
# 187   d__Bacteria  p__Firmicutes  c__Bacilli  o__Lactobacillales
#
#                    Family                 Genus  \
# 2322     f__Aerococcaceae         g__Aerococcus
# 209      f__Aerococcaceae         g__Aerococcus
# 1379     f__Aerococcaceae         g__Aerococcus
# 250      f__Aerococcaceae         g__Aerococcus
# 373    f__Enterococcaceae     g__Enterococcus_B
# ...                   ...                   ...
# 37              f__UBA660            g__CAG-877
# 2098  f__Lactobacillaceae  g__Ligilactobacillus
# 2173            f__UBA660           g__CAG-1193
# 231   f__Lactobacillaceae  g__Ligilactobacillus
# 187   f__Lactobacillaceae  g__Ligilactobacillus
#
#                               Species sample  cluster
# 2322         s__Aerococcus urinaeequi     S8        7
# 209          s__Aerococcus urinaeequi    S14        7
# 1379         s__Aerococcus urinaeequi     S3        7
# 250          s__Aerococcus urinaeequi    S15        7
# 373         s__Enterococcus_B faecium    S19       39
# ...                               ...    ...      ...
# 37                                s__    S11    10001
# 2098  s__Ligilactobacillus salivarius    S55    13176
# 2173                              s__     S6    25284
# 231   s__Ligilactobacillus salivarius    S15    25531
# 187     s__Ligilactobacillus aviarius    S14    26133
#
# [519 rows x 13 columns]

# %%
Bacillus_df['Genus'].unique()
# Out:
# array(['g__Aerococcus', 'g__Enterococcus_B', 'g__Holdemania',
#        'g__Streptococcus', 'g__Nosocomiicoccus', 'g__Limosilactobacillus',
#        'g__Weissella', 'g__HGM10873', 'g__Merdibacter',
#        'g__Jeotgalicoccus', 'g__Staphylococcus',
#        'g__Pseudogracilibacillus', 'g__Lactobacillus', 'g__Turicibacter',
#        'g__Atopostipes', 'g__Staphylococcus_A', 'g__Massilicoli',
#        'g__Erysipelatoclostridium', 'g__Ligilactobacillus', 'g__UMGS2068',
#        'g__Jeotgalicoccus_A', 'g__CAG-988', 'g__UMGS268',
#        'g__Facklamia_A', 'g__Enterococcus', 'g__CAG-451',
#        'g__Faecalicoccus', 'g__CAG-594', 'g__CAG-822', 'g__Globicatella',
#        'g__Enterococcus_E', 'g__Levilactobacillus', 'g__Paenibacillus',
#        'g__CAG-877', 'g__UBA733', 'g__CAG-776', 'g__Companilactobacillus',
#        'g__', 'g__Ureaplasma', 'g__Amedibacterium', 'g__Kurthia',
#        'g__CAG-1193', 'g__UBA4855', 'g__Aliicoccus', 'g__CAG-460',
#        'g__Atopococcus', 'g__Faecalitalea'], dtype=object)
